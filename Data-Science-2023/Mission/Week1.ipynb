# %% [markdown]
# # Q1.
# * 여러분은 파이썬을 통해 설문조사 문항의 응답내역을 분석하게 되었습니다. 문항별 응답내용에는 하나의 응답만 할 수 있는 single choice 문제와 여러 응답을 선택할 수 있는 multiple choice 문제가 있습니다. 2개를 구분하기 위해 single choice 문항 번호에 "_"를 표기하지 않기로 했습니다.
#
# * 문항별 응답내역이 'question'에 담겨 있을 때, 조건문과 반복문을 사용하여 아래와 같은 결과가 출력되도록 코드를 작성해보세요.
#
# ```python
# #응답 설문 문항
#     question = ['Q2', 'Q3', 'Q4', 'Q5', 'Q6_1', 'Q6_2', 'Q6_3', 'Q6_4', 'Q6_5', 'Q6_6',
#            'Q6_7', 'Q6_8', 'Q6_9', 'Q6_10', 'Q6_11', 'Q6_12', 'Q7_1', 'Q7_2',
#            'Q7_3', 'Q7_4', 'Q7_5', 'Q7_6', 'Q7_7', 'Q8', 'Q9', 'Q10_1', 'Q10_2',
#            'Q10_3']
#
# #출력 예시
#     ['Q2', 'Q3', 'Q4', 'Q5', 'Q8', 'Q9']
# ```

# %%
question = ['Q2', 'Q3', 'Q4', 'Q5', 'Q6_1', 'Q6_2', 'Q6_3', 'Q6_4', 'Q6_5', 'Q6_6',
           'Q6_7', 'Q6_8', 'Q6_9', 'Q6_10', 'Q6_11', 'Q6_12', 'Q7_1', 'Q7_2',
           'Q7_3', 'Q7_4', 'Q7_5', 'Q7_6', 'Q7_7', 'Q8', 'Q9', 'Q10_1', 'Q10_2',
           'Q10_3']
result = []

for response in question:
    if ("_" in response) == False:
        result.append(response)

result
# Out:
# ['Q2', 'Q3', 'Q4', 'Q5', 'Q8', 'Q9']

# %% [markdown]
# # Q2.
# * 한스 로슬링(Hans Rosling, 1948년 7월 27일 ~ 2017년 2월 7일)은 스웨덴의 의사이자 통계학자로 비영리 벤처 갭마인더 재단의 공동설립자이기도 합니다. 빅데이터를 가장 잘 활용하는 보건 통계학자로 알려져 있습니다. 베스트셀러 책인 "팩트풀니스" 저자이기도 합니다. 갭마인더 사이트에서는 연도별, 국가별 GDP와 기대수명 데이터를 제공하고 있는데, 대표적으로 파이썬 라이브러리 중 'seaborn'에서 제공되는 예제 데이터가 있습니다. 오늘은 이 데이터를 활용해 문제를 풀어보겠습니다.
# * 다음의 데이터는 연도, 국가별 기대수명을 나타내고 있는 데이터 입니다. 2011년 부터의 연도별, 국가별 평균 기대수명을 구해주세요. (2011년도 포함되게 구합니다.)
#
#     - [필수 조건] groupby 나 pivot_table을 활용합니다. groupby 로 구할 때 unstack()이라는 기능을 사용하여 아래와 같이 컬럼에 인덱스 값을 올려서 표기할 수 있습니다.
#     - 만약 행에는 '연도'가, 열에 '국가'가 들어있고 수치 데이터의 결과값이 아래와 같다면, 출력형태는 조금 달라도 괜찮습니다.
#     - 데이터는 다음의 방법으로 읽어옵니다.
#     ```python
#     import pandas as pd
#
#     df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/healthexp.csv")
#     df
#
#     # 출력 예시
#     ```
#     ![image-3.png](attachment:image-3.png)

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/mwaskom/seaborn-data/master/healthexp.csv")

# %%
filter_groupby = df[df['Year'] >= 2011]

filter_groupby.groupby(['Year', 'Country'])['Life_Expectancy'].mean().unstack()
# Out:
# Country  Canada  France  Germany  Great Britain  Japan   USA
# Year
# 2011       81.4    82.3     80.5           81.0   82.7  78.7
# 2012       81.6    82.1     80.6           81.0   83.2  78.8
# 2013       81.7    82.3     80.6           81.1   83.4  78.8
# 2014       81.8    82.8     81.2           81.4   83.7  78.9
# 2015       81.9    82.4     80.7           81.0   83.9  78.7
# 2016       82.0    82.7     81.0           81.2   84.1  78.7
# 2017       81.9    82.7     81.1           81.3   84.2  78.6
# 2018       82.0    82.8     81.0           81.3   84.3  78.7
# 2019       82.2    82.9     81.3           81.4   84.4  78.8
# 2020       81.7    82.3     81.1           80.4   84.7  77.0

# %%
filter_pivot = df[df['Year'] >= 2011]

pd.pivot_table(filter_pivot, index='Year', columns='Country', values='Life_Expectancy')
# Out:
# Country  Canada  France  Germany  Great Britain  Japan   USA
# Year
# 2011       81.4    82.3     80.5           81.0   82.7  78.7
# 2012       81.6    82.1     80.6           81.0   83.2  78.8
# 2013       81.7    82.3     80.6           81.1   83.4  78.8
# 2014       81.8    82.8     81.2           81.4   83.7  78.9
# 2015       81.9    82.4     80.7           81.0   83.9  78.7
# 2016       82.0    82.7     81.0           81.2   84.1  78.7
# 2017       81.9    82.7     81.1           81.3   84.2  78.6
# 2018       82.0    82.8     81.0           81.3   84.3  78.7
# 2019       82.2    82.9     81.3           81.4   84.4  78.8
# 2020       81.7    82.3     81.1           80.4   84.7  77.0

# %% [markdown]
# # Q3.
# - Jupyter notebook 은 문서와 코드를 함께 작성할 수 있다는 점이 장점입니다. Jupyter notebook 에서 지원하는 Markdown 문법을 사용하여, 이번 주에 배운 내용을 정리해 보세요!

# %% [markdown]
# ### 데이터 분석 환경 구성
#
# 1. 아나콘다 설치
#     - 파이썬과 관련된 다양한 환경을 가지고 있음
#     - [아나콘다](https://www.anaconda.com/download)
# 2. 주피터 랩과 주피터 노트북
#     - 주피터 노트북
#         - 하나의 웹에서 하나의 노트북 실행
#         - 콘솔에서 코드를 실행할 때 웹에서 바로 보일 수 있음
#         - 문서화를 하기에 좋은 환경
#         - 폴더 기능을 통해 정리하면 찾기 수월함
#         - new를 통해 파이썬 실행 및 폴더, txt 파일 등을 생성할 수 있음
#         ![image.png](attachment:image.png)
#         - 단축키 확인 'h'
#     - 주피터 랩
#         - 주피터 노트북의 상위버전
#         - 하나의 화면에서 화면 분할로 여러 노트북을 오픈 할 수 있음
#     - 마크다운
#         - 주피터에서 코드와 함께 문서화 할 수 있는 문법
#         - \# : 헤더 기능 갯수가 많을 수록 크기가 줄어듬
#         - \> : 인용구
#         - -/* 등 : 순서가 없는 리스트
#         - \1. /2. : 순서가 있는 리스트
#         - \<br> : 줄바꿈
#         - [설명] (링크) : 링크 걸 때 그냥 url 그대로 써도 가능
#         - 이미지, 테이블, 수식, 수평선 등 다양한 문법이 있음
#
#
# ### 데이터 분석 준비하기
# 1. 파이썬 기초
#     - Zen of Python
#         - 파이썬의 철학이 담겨 있음 (이스터에그)
#         - import this
#         - import : 파이썬의 라이브러리나 패키지를 가져올 수 있음
#     - boolean
#         - >파이썬의 철학<br>명시적인 것이 암시적인 것보다 낫다
#         - true/false = 0/1 이지만 명시적인 표현을 위해 true/false 사용
#     - Strings and lists
#         - string과 list 가 사용할 수 있는 함수는 다름
#     - 제어문
#         - 반복문 for
#         ```python
#         for (변수) in (list/range(반복횟수)):
#
#         for (인덱스 번호), (원소) in enumerate(list):
#         ```
#         - 조건문 if
#         ```python
#         if (조건):
#         ```
#     - 문자열
#         - strip() : 앞뒤 공백 제거
#         - len : 문자열/리스트 길이
#         - split() : 공백으로 문자열 분리
#         - list:[a:b] : a 부터 b 까지 위치한 길이의 문자
#         - startswith("") : 특정 문자가 포함 되는지 여부
#         - "" in list : 특정 문자열을 포함하고 있는지 여부
#     - 리스트
#         - 인덱싱으로 리스트의 원소를 가져올 수 있음
#         - -1 : 리스트의 마지막
#         - " ".join(list) : 리스트를 공백 문자열로 연결
#         - "" in list : 특정 문자열을 포함하고 있는지 여부 단 완전 일치해야함 일부 일치=false
# 2. 판다스
#     - 수식으로 계산 및 시각화 할 수 있는 데이터 분석 도구
#     - 엑셀과 비슷한 기능이지만 대용량 데이터 분석이 가능
#     - 10 minutes to pandas를 실행해보는 것을 권장
#     ```python
#     import pandas as pd
#     ```
#
#     1. DataFrame
#         - 공식문서 : pd.DataFrame?
#         - 2차원의 자료 구조 : 행렬
#     2. Series
#         - 1차원의 자료 구조 : 벡터
#         - df["a"]
#         - df[["a"]] : Series → DataFrame
#     3. Subset
#         - 일부 값만 불러오기
#         ```python
#         #Row 기준
#         df[df.Length > 7]
#         #Columns 기준
#         df["a"]
#         #2개 이상의 값은 DataFrame 형태
#         df[["a", "b"]]
#         ```
#     4. Summearize Data
#         - Categorical한 값의 빈도수를 구하는 방법
#         ```python
#         df["a"].value_counts()
#         len(df)
#         ```
#     5. Reshaping
#         - sort_values : 정렬
#             ```python
#             #칼럼 기준
#             df[""].sort_values()
#
#             #DataFrame 전체에서 값 기준
#             df.sort_values("a")
#
#             #역순
#             df.sort_values("a", asceding=False)
#             ```
#         - drop : 제거_행:0/열:1 | 할당해줘야 반영
#             ```python
#             df = df.drop(["c"], axis = 1)
#             df
#             ```
#     6. Group Data
#         - 데이터 집계시 사용
#         - Groupby : a 기준으로 b의 평균값
#             ```python
#             df.groupby(["a"])["b"].agg(["mean", "sum", "count"])
#
#             # 한번에 데이터 요약
#             df.groupby(["a"])["b"].describe()
#             ```
#         - pivot_table : pivot은 형태만 변경하지만 pivot_table은 연산을 할 수 있음 | 기본: 평균값
#             ```python
#             pd.pivot_table(df, index="a", values="b", aggfunc="sum")
#             ```
#     7. Plotting
#         - 다양한 시각화
#         - plot() 꺽은선 그래프
#             - plot.bar() 막대 그래프
#             - plot.density() 밀도함수
# 3. 파일 경로 설정
#     - 절대 경로
#         - 웹페이지나 파일이 가진 고유한 경로
#         - 최상위 디렉토리가 포함된 경로
#     - 상대 경로
#         - 현재 위치한 곳을 기준으로 하는 경로
#         - / : 절대 경로
#         - ./ : 현재 위치
#     1. 실습 파일 경로 확인
#         - pwd
#         -
#             ```python
#             import os
#             os.getcwd()
#             ```
#     2. 파일 불러오기
#         ```python
#         import pandas as pd
#         pd.read_csv("../Data/도로교통공단_월별 주야별 교통사고 통계_20221231.csv", encoding="cp949")
#         ```
#         - FileNotFoundError : 파일명이 하나라도 다르면 나오는 에러 <br>
#             폴더가 다를 경우 폴더 경로도 정확해야함
#         - 한글파일 인코딩을 하지 않으면 오류 : encoding="cp949"
#         - glob : 유닉스 스타일 경로명 패턴 확장 | 변수에 저장해 활용
#             ```python
#                 from glob import glob
#                 glob("data/* ")
#             ```
#         - 한글의 인코딩 방식이 운영체제에 따라 달라서 이름은 영어로 바꾸는 것이 좋음
#         - 여러 파일 한번에 로드
#             ```python
#             from glob import glob
#             file_csv = glob("../Data/store/* .csv")
#
#             import pandas as pd
#
#             file_list = []
#
#             for file_csv_name in file_csv:
#                 temp = pd.read_csv(file_csv_name, low_memory=False)
#                 file_list.append(temp)
#
#             #파일 합치기
#             df = pd.concat(file_list)
#             df.shape
#
#             df.info()
#             ```

# %% [markdown]
# # Q4.
# - 앞으로 우리는 공공데이터포털에서 데이터를 다운로드 받아 과정을 진행할 예정입니다. 본격적인 학습 이전에! 데이터를 다루는 방법이 익숙해지도록 한번 더 연습해보고, 어떤 문제를 풀 수 있을지도 함께 고민해보아요!
#     - 공공데이터포털에서 원하는 데이터를 다운로드 받아 경로를 설정하고, 주피터 노트북과 판다스를 통해 불러와 보세요!  <br>어떤 데이터를 사용해야할지 고민된다면 다음 링크의 데이터를 다운로드 받아도 좋습니다.  <br>[참고 예시 공공데이터포털 - 서울특별시 강남구_생활폐기물배출량](https://www.data.go.kr/data/15107375/fileData.do)
#     - 이 때, 인코딩 오류가 발생한다면 encoding="cp949" 옵션을 사용해 주세요!  <br>cp949는 한글 윈도우에서 사용하는 인코딩 방식이랍니다. 인코딩과 관련된 자세한 내용은 다음을 참고해 주세요.  <br>[문자 인코딩 - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/%EB%AC%B8%EC%9E%90_%EC%9D%B8%EC%BD%94%EB%94%A9)  <br>[파일을 열거나 저장할 때 텍스트 인코딩 선택](https://support.microsoft.com/ko-kr/office/%ED%8C%8C%EC%9D%BC%EC%9D%84-%EC%97%B4%EA%B1%B0%EB%82%98-%EC%A0%80%EC%9E%A5%ED%95%A0-%EB%95%8C-%ED%85%8D%EC%8A%A4%ED%8A%B8-%EC%9D%B8%EC%BD%94%EB%94%A9-%EC%84%A0%ED%83%9D-60d59c21-88b5-4006-831c-d536d42fd861)
#
#
# __답변 예시__
# ![image.png](attachment:image.png)

# %%
import pandas as pd

from glob import glob
file_name = glob("../Data/서울특별시 강남구_생활폐기물배출량_20221019.csv")

pd.read_csv(file_name[0], encoding="cp949", low_memory=False)
# Out:
#     강남구  2019년(생활폐기물)-톤  2020년(생활폐기물)-톤
# 0   01월            7550            7350
# 1   02월            6387            6688
# 2   03월            7198            6973
# 3   04월            6820            6448
# 4   05월            7767            6470
# 5   06월            7275            7923
# 6   07월            8164            8015
# 7   08월            7807            7859
# 8   09월            6811            7452
# 9   10월            7222            6875
# 10  11월            7592            7337
# 11  12월            7298            6911
