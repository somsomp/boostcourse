# %% [markdown]
# ## 1주차 미션 소개 - 머신러닝 과정 이해하기
#
# * 미션 목적
#     * 머신러닝 모델을 실행하는 기본 과정을 이해하기 (학습 => 예측 => 평가)
#     * Scikit-learn API 기본 사용법 익히기
#     * 학습을 하기 위해 학습, 예측 데이터를 나누는 방법
#     * 학습(train, 기출문제, 정답이 있음), 예측(test, 실전 문제, 정답이 없음)
#     * 학습(fit)과 예측(predict)을 하고 평가를 하는 방법
#     * 머신러닝 알고리즘 중에 좋은 성능을 내는 boosting 알고리즘의 기본이 되는 DecisionTree 를 사용
#     * DecisionTree 의 기본적인 원리 이해하기
#
# * 미션 데이터셋 소개
#
#     * 해당 Kaggle 데이터셋( https://www.kaggle.com/blastchar/telco-customer-churn )은 통신사 고객 이탈(Churn)에 대한 정보를 담고 있습니다. IBM에서 제공한 이 데이터셋은 고객 유지에 필요한 행동을 예측하는 데 사용될 수 있으며, 고객 데이터를 분석하여 고객 유지 프로그램을 개발하는 데 도움이 됩니다.
#     * 해당 데이터셋은 다음의 정보로 구성되어 있습니다.
#         * 고객 인구 통계 정보(Demographic info): 고객의 성별, 연령대, 배우자 및 부양 가족의 유무(Gender, SeniorCitizen, Partner, Dependents) 등에 관한 정보가 포함되어 있습니다.
#         * 고객 이탈(Churn) 정보: 서비스를 중단 여부에 대한 정보가 포함되어 있습니다.
#         * 서비스 가입 정보(Services subscribed): 고객들이 가입한 서비스들, 예를 들어 전화, 다중 라인, 인터넷, 온라인 보안, 온라인 백업, 장치 보호, 기술 지원, 스트리밍 TV 및 영화( honeService, MultipleLine, InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies) 등에 대한 정보가 있습니다.
#         * 고객 계정 정보(Customer account info): 고객이 얼마나 오래 서비스를 이용했는지, 계약 유형, 결제 방법, 무페이퍼 청구 여부, 월별 요금, 총 요금 (CustomerID, Contract, PaperlessBilling, PaymentMethod, MonthlyCharges, TotalCharges, Tenure)등의 정보가 담겨 있습니다.
#
#
# * 해당 미션으로 시도해 볼 수 있는 현실 세계 문제
#     * 이탈 예측 모델링: 가장 일반적인 사용 사례로, 고객의 이탈 가능성을 예측하는 모델을 구축합니다. 이러한 모델은 고객의 과거 데이터와 행동 패턴을 분석하여 누가 이탈할 가능성이 높은지 예측합니다.
#
#     * 고객 세분화: 고객을 다양한 그룹으로 세분화하여, 특정 그룹이 왜 더 높은 이탈률을 보이는지 이해할 수 있습니다. 이를 통해 타겟 마케팅 전략을 개발하거나 특정 고객 그룹에 더 맞춤화된 서비스를 제공할 수 있습니다.
#
#     * 원인 분석: 머신러닝 모델을 사용하여 고객 이탈의 주요 원인을 파악할 수 있습니다. 예를 들어, 서비스 품질, 가격, 고객 서비스 경험 등 다양한 요인이 고객 이탈에 어떤 영향을 미치는지 분석할 수 있습니다. 피처의 중요도를 파악하고 어떤 요인이 이탈의 중요한 피처인지를 확인해 봅니다.
#
#     * 추천 시스템 개선: 이탈 위험이 있는 고객에게 맞춤형 서비스나 제품을 추천하여 고객 만족도를 높이고 이탈률을 줄일 수 있습니다.
#
#     * 고객 유지 전략 개발: 이탈 예측 모델을 활용해 고위험 고객을 식별하고, 이들을 대상으로 특별 프로모션, 개선된 고객 서비스, 맞춤형 커뮤니케이션 전략 등을 제공하여 이탈률을 줄일 수 있습니다.
#
#     * 정책 및 서비스 개선: 모델에서 도출된 인사이트를 바탕으로 비즈니스 정책, 제품, 서비스를 개선하여 전반적인 고객 경험을 향상시킬 수 있습니다.

# %%
# 미션 진행을 위해 필요한 라이브러리를 로드합니다.
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# 미션 수행을 위해 데이터를 로드합니다.
df = pd.read_csv("https://bit.ly/telco-csv", index_col="customerID")
df.shape
# Out:
# (7043, 20)

# %%
# 데이터 프레임에서 가장 앞에 있는 N개의 행을 출력합니다.
df.head(2)
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female              0     Yes         No       1           No
# 5575-GNVDE    Male              0      No         No      34          Yes
#
#                MultipleLines InternetService OnlineSecurity OnlineBackup  \
# customerID
# 7590-VHVEG  No phone service             DSL             No          Yes
# 5575-GNVDE                No             DSL            Yes           No
#
#            DeviceProtection TechSupport StreamingTV StreamingMovies  \
# customerID
# 7590-VHVEG               No          No          No              No
# 5575-GNVDE              Yes          No          No              No
#
#                   Contract PaperlessBilling     PaymentMethod  MonthlyCharges  \
# customerID
# 7590-VHVEG  Month-to-month              Yes  Electronic check           29.85
# 5575-GNVDE        One year               No      Mailed check           56.95
#
#            TotalCharges Churn
# customerID
# 7590-VHVEG        29.85    No
# 5575-GNVDE       1889.5    No

# %%
# 데이터 집합과 각 열들의 자료형을 확인합니다.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
#  16  PaymentMethod     7043 non-null   object
#  17  MonthlyCharges    7043 non-null   float64
#  18  TotalCharges      7043 non-null   object
#  19  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(17)
# memory usage: 1.1+ MB

# %%
# df.isnull().sum()는 컬럼별로 결측치의 합계를 구합니다.
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
# df.isnull().sum().sum() 전체 결측치의 합계를 구합니다.
df.isnull().sum().sum()
# Out:
# 0

# %%
# 숫자형태로 된 문자열을 숫자형으로 바꿔줍니다.
# 공백문자 등의 결측치가 들어있다면 .str.strip()을 통해 공백문자를 제거합니다.
# .replace("", np.nan) 는 공백문자를 결측치로 변경해 줍니다.
# .astype(float) 으로 수치형태로 변환해 줍니다.
df["TotalCharges"] = df["TotalCharges"].str.strip().replace("", np.nan).astype(float)

# %%
df["TotalCharges"].head(1)
# Out:
# customerID
# 7590-VHVEG    29.85
# Name: TotalCharges, dtype: float64

# %%
# 결측치를 채워주는 방법도 있지만 일단 제거하도록 합니다.
# 결측치를 채우는 방법도 여러 가지가 있는데 여기에서는 결측치 11개는 그렇게 결측치가 많은 편이 아니고
# 임의의 수로 채워준다면 실제값과 유사한 값을 알아서 채워주지 않으면 오히려 예측의 성능이 떨어질 수 있습니다.
# 예를 들어 아무숫자로 채우기위해 0으로 채운다면 실제 낸 금액은 훨씬 많을텐데 모델을 더 혼란스럽게 만들 수 있습니다.
# 중간값, 평균값 등의 대푯값으로 채운다면 해당 데이터에서 제공하는
# 인구통계학적인 정보, 구독정보 등을 참고해서 해당 세그먼트에서의 대푯값으로 채우는 것을 추천합니다.
df = df.dropna()
df.isnull().sum().sum()
# Out:
# 0

# %%
# 바이너리 변수 인코딩을 위해 범주 값이 2개로 되어 있어 이진값으로 인코딩이 가능한 변수를 찾습니다.
nuniq = df.nunique()
bi_cols = nuniq[nuniq == 2].index
bi_cols
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService',
#        'PaperlessBilling', 'Churn'],
#       dtype='object')

# %%
df[bi_cols]
# Out:
#             gender  SeniorCitizen Partner Dependents PhoneService  \
# customerID
# 7590-VHVEG  Female              0     Yes         No           No
# 5575-GNVDE    Male              0      No         No          Yes
# 3668-QPYBK    Male              0      No         No          Yes
# 7795-CFOCW    Male              0      No         No           No
# 9237-HQITU  Female              0      No         No          Yes
# ...            ...            ...     ...        ...          ...
# 6840-RESVB    Male              0     Yes        Yes          Yes
# 2234-XADUH  Female              0     Yes        Yes          Yes
# 4801-JZAZL  Female              0     Yes        Yes           No
# 8361-LTMKD    Male              1     Yes         No          Yes
# 3186-AJIEK    Male              0      No         No          Yes
#
#            PaperlessBilling Churn
# customerID
# 7590-VHVEG              Yes    No
# 5575-GNVDE               No    No
# 3668-QPYBK              Yes   Yes
# 7795-CFOCW               No    No
# 9237-HQITU              Yes   Yes
# ...                     ...   ...
# 6840-RESVB              Yes    No
# 2234-XADUH              Yes    No
# 4801-JZAZL              Yes    No
# 8361-LTMKD              Yes   Yes
# 3186-AJIEK              Yes    No
#
# [7032 rows x 7 columns]

# %%
# 바이너리 변수에 대한 인코딩
df["gender_encode"] = (df["gender"] == "Male").astype(int)
df["Partner_encode"] = (df["Partner"] == "Yes").astype(int)
df["Dependents_encode"] = (df["Dependents"] == "Yes").astype(int)
df["PhoneService_encode"] = (df["PhoneService"] == "Yes").astype(int)
df["PaperlessBilling_encode"] = (df["PaperlessBilling"] == "Yes").astype(int)
df
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female              0     Yes         No       1           No
# 5575-GNVDE    Male              0      No         No      34          Yes
# 3668-QPYBK    Male              0      No         No       2          Yes
# 7795-CFOCW    Male              0      No         No      45           No
# 9237-HQITU  Female              0      No         No       2          Yes
# ...            ...            ...     ...        ...     ...          ...
# 6840-RESVB    Male              0     Yes        Yes      24          Yes
# 2234-XADUH  Female              0     Yes        Yes      72          Yes
# 4801-JZAZL  Female              0     Yes        Yes      11           No
# 8361-LTMKD    Male              1     Yes         No       4          Yes
# 3186-AJIEK    Male              0      No         No      66          Yes
#
#                MultipleLines InternetService OnlineSecurity OnlineBackup  ...  \
# customerID                                                                ...
# 7590-VHVEG  No phone service             DSL             No          Yes  ...
# 5575-GNVDE                No             DSL            Yes           No  ...
# 3668-QPYBK                No             DSL            Yes          Yes  ...
# 7795-CFOCW  No phone service             DSL            Yes           No  ...
# 9237-HQITU                No     Fiber optic             No           No  ...
# ...                      ...             ...            ...          ...  ...
# 6840-RESVB               Yes             DSL            Yes           No  ...
# 2234-XADUH               Yes     Fiber optic             No          Yes  ...
# 4801-JZAZL  No phone service             DSL            Yes           No  ...
# 8361-LTMKD               Yes     Fiber optic             No           No  ...
# 3186-AJIEK                No     Fiber optic            Yes           No  ...
#
#            PaperlessBilling              PaymentMethod MonthlyCharges  \
# customerID
# 7590-VHVEG              Yes           Electronic check          29.85
# 5575-GNVDE               No               Mailed check          56.95
# 3668-QPYBK              Yes               Mailed check          53.85
# 7795-CFOCW               No  Bank transfer (automatic)          42.30
# 9237-HQITU              Yes           Electronic check          70.70
# ...                     ...                        ...            ...
# 6840-RESVB              Yes               Mailed check          84.80
# 2234-XADUH              Yes    Credit card (automatic)         103.20
# 4801-JZAZL              Yes           Electronic check          29.60
# 8361-LTMKD              Yes               Mailed check          74.40
# 3186-AJIEK              Yes  Bank transfer (automatic)         105.65
#
#            TotalCharges Churn gender_encode Partner_encode  Dependents_encode  \
# customerID
# 7590-VHVEG        29.85    No             0              1                  0
# 5575-GNVDE      1889.50    No             1              0                  0
# 3668-QPYBK       108.15   Yes             1              0                  0
# 7795-CFOCW      1840.75    No             1              0                  0
# 9237-HQITU       151.65   Yes             0              0                  0
# ...                 ...   ...           ...            ...                ...
# 6840-RESVB      1990.50    No             1              1                  1
# 2234-XADUH      7362.90    No             0              1                  1
# 4801-JZAZL       346.45    No             0              1                  1
# 8361-LTMKD       306.60   Yes             1              1                  0
# 3186-AJIEK      6844.50    No             1              0                  0
#
#             PhoneService_encode PaperlessBilling_encode
# customerID
# 7590-VHVEG                    0                       1
# 5575-GNVDE                    1                       0
# 3668-QPYBK                    1                       1
# 7795-CFOCW                    0                       0
# 9237-HQITU                    1                       1
# ...                         ...                     ...
# 6840-RESVB                    1                       1
# 2234-XADUH                    1                       1
# 4801-JZAZL                    0                       1
# 8361-LTMKD                    1                       1
# 3186-AJIEK                    1                       1
#
# [7032 rows x 25 columns]

# %%
# 정답의 빈도수 확인
df["Churn"].value_counts()
# Out:
# No     5163
# Yes    1869
# Name: Churn, dtype: int64

# %%
# value_counts(1) => normalize=True 와 같습니다.
df["Churn"].value_counts(1)
# Out:
# No     0.734215
# Yes    0.265785
# Name: Churn, dtype: float64

# %%
sns.countplot(data=df, x="Churn")
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %% [markdown]
# ## 미션 1) - 학습, 예측 데이터셋 나누기
#
# <img src="https://i.imgur.com/yvBtRtJ.png" width="600">
#
# * X_train : feature_names 에 해당되는 컬럼만 train에서 가져옵니다.
#     * 학습(훈련)에 사용할 데이터셋 예) 시험의 기출문제
#
# * X_test : feature_names 에 해당되는 컬럼만 test에서 가져옵니다.
#     * 예측에 사용할 데이터셋 예) 실전 시험문제
#
# * y_train : label_name 에 해당 되는 컬럼만 train에서 가져옵니다.
#     * 학습(훈련)에 사용할 정답 값 예) 기출문제의 정답
#
# * y_test : label_name 에 해당 되는 컬럼만 test에서 가져옵니다.
#     * 예측에 사용할 정답 값 예) 실전 문제의 정답
#
#
# * 아래의 형태로 데이터셋을 나누되, train 데이터셋의 shape 는 (5625, 9), test 데이터셋의 shape 는 (1407, 9) 이 되도록 합니다. 행의 customerID 는 섞여도 상관 없으며 아래와 순서가 달라도 되며, train, test의 shape 값의 행의 수가 8:2 로 나뉘면 됩니다.
#
#
# | customerID   |   SeniorCitizen |   tenure |   MonthlyCharges |   TotalCharges |   gender_encode |   Partner_encode |   Dependents_encode |   PhoneService_encode |   PaperlessBilling_encode |
# |:-------------|----------------:|---------:|-----------------:|---------------:|----------------:|-----------------:|--------------------:|----------------------:|--------------------------:|
# | 7590-VHVEG   |               0 |        1 |            29.85 |          29.85 |               0 |                1 |                   0 |                     0 |                         1 |
# | 5575-GNVDE   |               0 |       34 |            56.95 |        1889.5  |               1 |                0 |                   0 |                     1 |                         0 |
#
#
# | customerID   |   SeniorCitizen |   tenure |   MonthlyCharges |   TotalCharges |   gender_encode |   Partner_encode |   Dependents_encode |   PhoneService_encode |   PaperlessBilling_encode |
# |:-------------|----------------:|---------:|-----------------:|---------------:|----------------:|-----------------:|--------------------:|----------------------:|--------------------------:|
# | 2320-JRSDE   |               0 |        1 |             19.9 |          19.9  |               0 |                1 |                   1 |                     1 |                         1 |
# | 2087-QAREY   |               0 |       22 |             54.7 |        1178.75 |               0 |                1 |                   0 |                     1 |                         1 |
#
#
#
# ### 학습, 예측에 사용할 컬럼

# %%
# 학습, 예측에 사용할 컬럼에 이름 지정합니다.
# 범주형 데이터(object, category)는 전처리가 따로 필요합니다.
# 간단하게 모델을 만들어보기 위해 수치 데이터만 사용합니다.
feature_names = df.select_dtypes(include="number").columns
feature_names
# Out:
# Index(['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges',
#        'gender_encode', 'Partner_encode', 'Dependents_encode',
#        'PhoneService_encode', 'PaperlessBilling_encode'],
#       dtype='object')

# %% [markdown]
# ### 정답값이자 예측해야 될 값

# %%
# label_name 이라는 변수에 예측할 컬럼(Churn)의 이름을 담습니다.
label_name = "Churn"
label_name
# Out:
# 'Churn'

# %% [markdown]
# ### 문제(feature)와 답안(label)을 나누기
#
# * X, y를 만들어 줍니다.
# * X는 feature, 독립변수, 예) 시험의 문제
# * y는 label, 종속변수, 예) 시험의 정답
#
# * 결과는 다음과 같은 형태로 나오도록 합니다.
#
# * X 값 출력 예시 입니다.
#
# | customerID   |   SeniorCitizen |   tenure |   MonthlyCharges |   TotalCharges |   gender_encode |   Partner_encode |   Dependents_encode |   PhoneService_encode |   PaperlessBilling_encode |
# |:-------------|----------------:|---------:|-----------------:|---------------:|----------------:|-----------------:|--------------------:|----------------------:|--------------------------:|
# | 7590-VHVEG   |               0 |        1 |            29.85 |          29.85 |               0 |                1 |                   0 |                     0 |                         1 |
# | 5575-GNVDE   |               0 |       34 |            56.95 |        1889.5  |               1 |                0 |                   0 |                     1 |                         0 |
#
#
# * y 값 출력 예시 입니다.
#
# | customerID   | Churn   |
# |:-------------|:--------|
# | 7590-VHVEG   | No      |
# | 5575-GNVDE   | No      |
#
# * 데이터의 행과 열의 수 입니다.
#     * X 의 shape 출력 (7032, 9)
#     * y 의 shape 출력 (7032,)

# %%
# X, y를 만들어 줍니다.
# 물음표를 채워 독립변수(X)와 종속변수(y)를 나눠주세요.
# scikit-learn에서 데이터는 대문자 X(2차원,행렬)로 표시하고 정답은 소문자 y(1차원,벡터)로 표기합니다.
X = df[feature_names]
y = df[label_name]
display(X.head(2))
display(y.head(2))
X.shape, y.shape
# Out:
#             SeniorCitizen  tenure  MonthlyCharges  TotalCharges  \
# customerID
# 7590-VHVEG              0       1           29.85         29.85
# 5575-GNVDE              0      34           56.95       1889.50
#
#             gender_encode  Partner_encode  Dependents_encode  \
# customerID
# 7590-VHVEG              0               1                  0
# 5575-GNVDE              1               0                  0
#
#             PhoneService_encode  PaperlessBilling_encode
# customerID
# 7590-VHVEG                    0                        1
# 5575-GNVDE                    1                        0
# customerID
# 7590-VHVEG    No
# 5575-GNVDE    No
# Name: Churn, dtype: object
# ((7032, 9), (7032,))

# %% [markdown]
# ### 학습, 예측 데이터셋 만들기
# * X_train : 학습 세트 만들기, 행렬, 판다스의 데이터프레임, 2차원 리스트(배열) 구조,  예) 시험의 기출문제
# * y_train : 정답 값을 만들기, 벡터, 판다스의 시리즈, 1차원 리스트(배열) 구조, 예) 기출문제의 정답
# * X_test : 예측에 사용할 데이터세트를 만듭니다. 예) 실전 시험 문제
# * y_test : 예측의 정답값 예) 실전 시험 문제의 정답
#
#
# * 10회까지의 모의고사 문제집이 있다고 가정할 때
# * 1~8회는 공부한다 풀어보고 : model.fit(X_train, y_train)
# * 9, 10회는 실전 문제처럼 풀어보고 : model.predict(X_test) => 결과를 y_predict 로 만들고
# * 채점하는 과정으로 학습과 예측을 할 예정입니다. : y_test, y_predict 실제값과 예측값을 비교해서 채점하게 됩니다.

# %%
# 데이터의 행과 열의 개수를 확인합니다.
df.shape
# Out:
# (7032, 25)

# %% [markdown]
# * 학습, 예측 데이터셋을 나눌 때는  5:5, 8:2, 7:3 등으로 나눌수도 있지만 학습데이터를 더 많이 나누는게 좋습니다.
# * 공부를 더 많이 하고 시험을 봐야지 시험을 더 잘 볼 수있기 때문입니다.
# * 8:2 를 기준으로 나눕니다. 아래의 내용은 tain.head(2), test.head(2)로 위에 있는 데이터를 미리보기 한 모습으로 예시 입니다.
#
#
# * X_train 출력 예시 입니다.
#
# | customerID   |   SeniorCitizen |   tenure |   MonthlyCharges |   TotalCharges |   gender_encode |   Partner_encode |   Dependents_encode |   PhoneService_encode |   PaperlessBilling_encode |
# |:-------------|----------------:|---------:|-----------------:|---------------:|----------------:|-----------------:|--------------------:|----------------------:|--------------------------:|
# | 7590-VHVEG   |               0 |        1 |            29.85 |          29.85 |               0 |                1 |                   0 |                     0 |                         1 |
# | 5575-GNVDE   |               0 |       34 |            56.95 |        1889.5  |               1 |                0 |                   0 |                     1 |                         0 |
#
# * X_test 출력 예시 입니다.
#
# | customerID   |   SeniorCitizen |   tenure |   MonthlyCharges |   TotalCharges |   gender_encode |   Partner_encode |   Dependents_encode |   PhoneService_encode |   PaperlessBilling_encode |
# |:-------------|----------------:|---------:|-----------------:|---------------:|----------------:|-----------------:|--------------------:|----------------------:|--------------------------:|
# | 2320-JRSDE   |               0 |        1 |             19.9 |          19.9  |               0 |                1 |                   1 |                     1 |                         1 |
# | 2087-QAREY   |               0 |       22 |             54.7 |        1178.75 |               0 |                1 |                   0 |                     1 |                         1 |
#
# * X_train, X_test 의 shape 출력 예시 입니다.
# (5625, 9), (1407, 9)

# %%
# train 과 test 로 나누기 위해 데이터를 기준을 정합니다.
split_count = int(df.shape[0] * 0.8)
split_count
# Out:
# 5625

# %% [markdown]
# * 다음 빈칸을 채워 학습, 예측 데이터셋을 만들어 주세요.
# * 빈칸을 채우는 방법 외 다른 방법으로 나눠도 됩니다.

# %%
# 데이터의 80%을 나눌 기준 인덱스(split_count)로 문제 데이터(X)를 train, test로 나눕니다.
# 데이터의 80%을 나눌 기준 인덱스(split_count)로 정답 데이터(y)를 train, test로 나눕니다.
X_train = X.iloc[:split_count]
y_train = y.iloc[:split_count]

X_test = X.iloc[split_count:]
y_test = y.iloc[split_count:]

print("* 데이터가 잘 나뉘었는지 shape 값을 통해 확인해 보세요.")

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# * 데이터가 잘 나뉘었는지 shape 값을 통해 확인해 보세요.
# ((5625, 9), (1407, 9), (5625,), (1407,))

# %% [markdown]
# 클래스가 여러 개 일 경우에 클래스의 수가 train, test에 균일하게 나뉘지 않을 수도 있습니다.
# train_test_split() 등의 기능을 사용하면 label값을 균형있게 나눠줄 수도 있습니다.
# 예를 들어 이탈여부를 예측하는데 이탈안한다 한다가 7:3 정도로 train에 있다면  test 에도 7:3 으로 들어있어야 제대로 학습하고 예측할 수 있습니다.
# 임의로 순서대로 나눴다면 train 에는 8:2 로 들어있는데 test 에는 6:4 로 들어있다면 예측의 성능이 떨어질 수도 있습니다.
# 불균형한 클래스를 다룰 때는 정답의 클래스를 같은 비율로 만들어 줄 때 언더샘플링, 오버샘플링(KNN) 등의 방법을 사용합니다.

# %% [markdown]
# ## 미션 2 - 머신러닝 알고리즘 모델을 통한 학습과 예측을 해주세요.
#
# * 강의에 있는 DecisionTree 를 사용해도 되며, 사이킷런의 다른 모델을 사용해도 됩니다.
# 다음과 같이 예측값이 나오도록 예측해 주세요.
# <font color="red"> 이탈여부의 Yes, No 는 예시로 다음의 결과와 달라도 상관 없습니다.</font>
#
# ```python
# # y_predict[:5] 를 출력했을 때 아래처럼 이탈 여부에 대한 값이 나옵니다.
# array(['No', 'No', 'No', 'No', 'No'], dtype=object)
# ```
#
# * 사이킷런에서 좋은 성능을 내고 주목받고 있는 알고리즘을 별도의 라이브러리로 공개되어 있는 것들이 다음과 같습니다.
#     * 부스팅계열 알고리즘(주로 정형 데이터) => XGBoost, LightGBM, CatBoost 등
#     * 신경망 알고리즘(주로 비정형 데이터) => TensorFlow, Keras, PyTorch 등
#
# * 알고리즘 중에는 분류, 회귀에 따로 사용할 수 있는 것도 있고, 분류, 회귀에 모두 사용할 수 있는 것도 있습니다.
#     * 회귀 알고리즘 => 분류(로지스틱 회귀), 회귀(릿지, 라쏘, 엘라스틱넷) 분류에 사용하는 알고리즘과 회귀에 사용하는게 다릅니다.
#     * 분류 및 회귀 트리(Classification And Regression Tree, CART) => 분류와 회귀에 모두 사용할 수 있습니다.
#
#
#
#
# * [참고 : 결정 트리 학습법 - 위키백과, 우리 모두의 백과사전](https://ko.wikipedia.org/wiki/%EA%B2%B0%EC%A0%95_%ED%8A%B8%EB%A6%AC_%ED%95%99%EC%8A%B5%EB%B2%95)
#     * 결과를 해석하고 이해하기 쉽다.간략한 설명만으로 결정 트리를 이해하는 것이 가능하다.
#     * 자료를 가공할 필요가 거의 없다.다른 기법들의 경우 자료를 정규화하거나 임의의 변수를 생성하거나 값이 없는 변수를 제거해야 하는 경우가 있다.
#     * 수치 자료와 범주 자료 모두에 적용할 수 있다.다른 기법들은 일반적으로 오직 한 종류의 변수를 갖는 데이터 셋을 분석하는 것에 특화되어 있다. (일례로 신경망 학습은 숫자로 표현된 변수만을 다룰 수 있는 것에 반해 관계식(relation rules)은 오직 명목 변수만을 다룰 수 있다.
#     * 화이트박스 모델을 사용한다. 모델에서 주어진 상황이 관측 가능하다면 불 논리를 이용하여 조건에 대해 쉽게 설명할 수 있다. (결과에 대한 설명을 이해하기 어렵기 때문에 인공신경망은 대표적인 블랙 박스 모델이다.)
#     * 안정적이다. 해당 모델 추리의 기반이 되는 명제가 다소 손상되었더라도 잘 동작한다.
#     * 대규모의 데이터 셋에서도 잘 동작한다. 방대한 분량의 데이터를 일반적인 컴퓨터 환경에서 합리적인 시간 안에 분석할 수 있다.
#
#
# ```python
# DecisionTreeClassifier(
#     *,
#     criterion='gini', # 분할방법 {"gini", "entropy"}, default="gini"
#     splitter='best',
#     max_depth=None, # The maximum depth of the tree
#     min_samples_split=2, # The minimum number of samples required to split an internal node
#     min_samples_leaf=1, # The minimum number of samples required to be at a leaf node.
#     min_weight_fraction_leaf=0.0, # The minimum weighted fraction of the sum total of weights
#     max_features=None, # The number of features to consider when looking for the best split
#     random_state=None,
#     max_leaf_nodes=None,
#     min_impurity_decrease=0.0,
#     class_weight=None,
#     ccp_alpha=0.0,
# )
# ```
#
# * 주요 파라미터
#     * criterion: 가지의 분할의 품질을 측정하는 기능입니다.
#     * max_depth: 트리의 최대 깊이입니다.
#     * min_samples_split:내부 노드를 분할하는 데 필요한 최소 샘플 수입니다.
#     * min_samples_leaf: 리프 노드에 있어야 하는 최소 샘플 수입니다.
#     * max_leaf_nodes: 리프 노드 숫자의 제한치입니다.
#     * random_state: 추정기의 무작위성을 제어합니다. 실행했을 때 같은 결과가 나오도록 합니다.
#
#
# ```python
# # max_depth == 1 트리의 깊이를 의미합니다.
# # max_features == 0.9 라면 전체 피처의 90% 만 사용합니다.
# from sklearn.tree import DecisionTreeClassifier
#
# model = DecisionTreeClassifier(criterion="gini",
#                                max_depth=15,
#                                max_features=0.9,
#                                random_state=42)
# model
# ```

# %% [markdown]
# * 머신러닝 모델의 성능을 개선하는 방법
#     * 데이터 분할
#     * 데이터 전처리, 결측치 처리
#     * 피처 선택, 피처 엔지니어링(스케일링, 변환, 인코딩 등)
#     * 모델의 `파라미터 값을 변경하는 방법`
#
# * <font color="red">머신러닝 알고리즘 모델을 통한 학습과 예측을 해주세요.</font>

# %%
# 사이킷런(sklearn)에서 의사 결정 트리 분류모델(DecisionTreeClassifier)을 로드합니다.
# 위 설명에서 제시한 주요 파라미터의 설정을 변경해서 모델을 만들어 주세요.
# 기본값으로 모델을 만들어도 되며 여러 파라미터를 변경하는 방법으로 만들어도 됩니다.

from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()

# %%
# 데이터를 머신러닝 모델로 학습(fit)합니다.
# 기출문제 X_train 와 기출문제의 정답 y_train 을 넣고 학습을 합니다.
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# 데이터를 머신러닝 모델로 예측(predict)합니다.
y_predict = model.predict(X_test)
y_predict[:5]
# Out:
# array(['Yes', 'Yes', 'Yes', 'No', 'Yes'], dtype=object)

# %% [markdown]
# ## 미션 3 - 점수 측정하고 피처의 중요도 시각화 하기
# * 예측한 데이터셋의 점수를 Accuracy로 측정하고 모델이 학습한 피처의 중요도를 시각화 해주세요.
# * 피처 중요도 이미지는 예시이며 다른 결과가 나와도 상관 없습니다. 또, 트리 계열 모델이 아닌 다른 모델로 학습했을 때도 해당 모델에 맞는 피처 중요도를 시각화 해주세요.
#
# ### 3-1) 트리 시각화 하기
#
# * 해당 이미지는 예시로 모델의 학습 결과에 따라 다르게 나올 수 있습니다.
#
# <img src="https://i.imgur.com/NgvuaC8.png" width="500">

# %%
# plot_tree 를 통해 tree 를 시각화 합니다.
# 시각화 할 때만 max_depth를 제한한것이고 실제 모델에서는 다른 값을 사용하게 됩니다.
# 위 예시 이미지를 참고합니다.
from sklearn.tree import plot_tree

plt.figure(figsize=(20, 10))
# 여기에 구현해 주세요.
plot_tree(model, feature_names=feature_names, filled=True, fontsize=10)
# Out:
# [Text(0.45327868735546495, 0.9848484848484849, 'tenure <= 16.5\ngini = 0.389\nsamples = 5625\nvalue = [4137, 1488]'),
#  Text(0.22254428287792113, 0.9545454545454546, 'MonthlyCharges <= 69.225\ngini = 0.496\nsamples = 2039\nvalue = [1113, 926]'),
#  Text(0.11752934441942552, 0.9242424242424242, 'tenure <= 2.5\ngini = 0.418\nsamples = 1134\nvalue = [797, 337]'),
#  Text(0.06262171372930866, 0.8939393939393939, 'MonthlyCharges <= 20.85\ngini = 0.496\nsamples = 413\nvalue = [225, 188]'),
#  Text(0.031037000973709834, 0.8636363636363636, 'TotalCharges <= 20.275\ngini = 0.402\nsamples = 158\nvalue = [114, 44]'),
#  Text(0.01436222005842259, 0.8333333333333334, 'TotalCharges <= 19.275\ngini = 0.469\nsamples = 96\nvalue = [60, 36]'),
#  Text(0.0019474196689386564, 0.803030303030303, 'PaperlessBilling_encode <= 0.5\ngini = 0.133\nsamples = 14\nvalue = [13, 1]'),
#  Text(0.0009737098344693282, 0.7727272727272727, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.0029211295034079843, 0.7727272727272727, 'MonthlyCharges <= 19.15\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.0019474196689386564, 0.7424242424242424, 'MonthlyCharges <= 19.05\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.0009737098344693282, 0.7121212121212122, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0029211295034079843, 0.7121212121212122, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0038948393378773127, 0.7424242424242424, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.026777020447906523, 0.803030303030303, 'SeniorCitizen <= 0.5\ngini = 0.489\nsamples = 82\nvalue = [47, 35]'),
#  Text(0.025803310613437196, 0.7727272727272727, 'MonthlyCharges <= 20.075\ngini = 0.485\nsamples = 80\nvalue = [47, 33]'),
#  Text(0.015092502434274586, 0.7424242424242424, 'gender_encode <= 0.5\ngini = 0.462\nsamples = 58\nvalue = [37, 21]'),
#  Text(0.004868549172346641, 0.7121212121212122, 'TotalCharges <= 19.35\ngini = 0.403\nsamples = 25\nvalue = [18, 7]'),
#  Text(0.0038948393378773127, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.005842259006815969, 0.6818181818181818, 'MonthlyCharges <= 19.425\ngini = 0.375\nsamples = 24\nvalue = [18, 6]'),
#  Text(0.004868549172346641, 0.6515151515151515, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.006815968841285297, 0.6515151515151515, 'PaperlessBilling_encode <= 0.5\ngini = 0.397\nsamples = 22\nvalue = [16, 6]'),
#  Text(0.004381694255111977, 0.6212121212121212, 'TotalCharges <= 19.525\ngini = 0.346\nsamples = 18\nvalue = [14, 4]'),
#  Text(0.0024342745861733205, 0.5909090909090909, 'MonthlyCharges <= 19.475\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.0014605647517039922, 0.5606060606060606, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.0034079844206426485, 0.5606060606060606, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.006329113924050633, 0.5909090909090909, 'TotalCharges <= 19.6\ngini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.005355404089581304, 0.5606060606060606, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.007302823758519961, 0.5606060606060606, 'MonthlyCharges <= 19.7\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.006329113924050633, 0.5303030303030303, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.008276533592989289, 0.5303030303030303, 'TotalCharges <= 19.875\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.007302823758519961, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.009250243427458617, 0.5, 'TotalCharges <= 19.925\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.008276533592989289, 0.4696969696969697, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.010223953261927946, 0.4696969696969697, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.009250243427458617, 0.6212121212121212, 'MonthlyCharges <= 19.575\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.008276533592989289, 0.5909090909090909, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.010223953261927946, 0.5909090909090909, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.02531645569620253, 0.7121212121212122, 'TotalCharges <= 20.025\ngini = 0.489\nsamples = 33\nvalue = [19, 14]'),
#  Text(0.021908471275559883, 0.6818181818181818, 'MonthlyCharges <= 19.875\ngini = 0.497\nsamples = 28\nvalue = [15, 13]'),
#  Text(0.019961051606621226, 0.6515151515151515, 'Partner_encode <= 0.5\ngini = 0.486\nsamples = 24\nvalue = [14, 10]'),
#  Text(0.0189873417721519, 0.6212121212121212, 'Dependents_encode <= 0.5\ngini = 0.499\nsamples = 21\nvalue = [11, 10]'),
#  Text(0.017039922103213243, 0.5909090909090909, 'TotalCharges <= 19.775\ngini = 0.494\nsamples = 18\nvalue = [10, 8]'),
#  Text(0.016066212268743916, 0.5606060606060606, 'MonthlyCharges <= 19.425\ngini = 0.469\nsamples = 16\nvalue = [10, 6]'),
#  Text(0.014118792599805257, 0.5303030303030303, 'MonthlyCharges <= 19.35\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.01314508276533593, 0.5, 'PaperlessBilling_encode <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.012171372930866602, 0.4696969696969697, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.014118792599805257, 0.4696969696969697, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.015092502434274586, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.01801363193768257, 0.5303030303030303, 'MonthlyCharges <= 19.525\ngini = 0.426\nsamples = 13\nvalue = [9, 4]'),
#  Text(0.017039922103213243, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.0189873417721519, 0.5, 'MonthlyCharges <= 19.625\ngini = 0.48\nsamples = 10\nvalue = [6, 4]'),
#  Text(0.01801363193768257, 0.4696969696969697, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.019961051606621226, 0.4696969696969697, 'PaperlessBilling_encode <= 0.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.0189873417721519, 0.4393939393939394, 'MonthlyCharges <= 19.7\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.01801363193768257, 0.4090909090909091, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.019961051606621226, 0.4090909090909091, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.020934761441090556, 0.4393939393939394, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.01801363193768257, 0.5606060606060606, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.020934761441090556, 0.5909090909090909, 'MonthlyCharges <= 19.8\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.019961051606621226, 0.5606060606060606, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.021908471275559883, 0.5606060606060606, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.020934761441090556, 0.6212121212121212, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.02385589094449854, 0.6515151515151515, 'TotalCharges <= 19.975\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.022882181110029213, 0.6212121212121212, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.024829600778967866, 0.6212121212121212, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.02872444011684518, 0.6818181818181818, 'Dependents_encode <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.027750730282375853, 0.6515151515151515, 'PaperlessBilling_encode <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.026777020447906523, 0.6212121212121212, 'gini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.02872444011684518, 0.6212121212121212, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.02969814995131451, 0.6515151515151515, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0365141187925998, 0.7424242424242424, 'MonthlyCharges <= 20.175\ngini = 0.496\nsamples = 22\nvalue = [10, 12]'),
#  Text(0.03261927945472249, 0.7121212121212122, 'TotalCharges <= 20.125\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.03164556962025317, 0.6818181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.03359298928919182, 0.6818181818181818, 'Dependents_encode <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.03164556962025317, 0.6515151515151515, 'gender_encode <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.030671859785783837, 0.6212121212121212, 'PaperlessBilling_encode <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.02969814995131451, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.03164556962025317, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.03261927945472249, 0.6212121212121212, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.03554040895813048, 0.6515151515151515, 'gender_encode <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.03456669912366115, 0.6212121212121212, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0365141187925998, 0.6212121212121212, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.04040895813047712, 0.7121212121212122, 'PaperlessBilling_encode <= 0.5\ngini = 0.49\nsamples = 14\nvalue = [8, 6]'),
#  Text(0.038461538461538464, 0.6818181818181818, 'MonthlyCharges <= 20.225\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.037487828627069134, 0.6515151515151515, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.03943524829600779, 0.6515151515151515, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.04235637779941578, 0.6818181818181818, 'Dependents_encode <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.04138266796494645, 0.6515151515151515, 'MonthlyCharges <= 20.225\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.04040895813047712, 0.6212121212121212, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.04235637779941578, 0.6212121212121212, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.0433300876338851, 0.6515151515151515, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.027750730282375853, 0.7727272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.04771178188899708, 0.8333333333333334, 'MonthlyCharges <= 20.475\ngini = 0.225\nsamples = 62\nvalue = [54, 8]'),
#  Text(0.04527750730282376, 0.803030303030303, 'MonthlyCharges <= 19.875\ngini = 0.124\nsamples = 45\nvalue = [42, 3]'),
#  Text(0.04430379746835443, 0.7727272727272727, 'TotalCharges <= 36.55\ngini = 0.32\nsamples = 15\nvalue = [12, 3]'),
#  Text(0.0433300876338851, 0.7424242424242424, 'TotalCharges <= 27.925\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.04235637779941578, 0.7121212121212122, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.04430379746835443, 0.7121212121212122, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.04527750730282376, 0.7424242424242424, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.046251217137293084, 0.7727272727272727, 'gini = 0.0\nsamples = 30\nvalue = [30, 0]'),
#  Text(0.0501460564751704, 0.803030303030303, 'TotalCharges <= 20.575\ngini = 0.415\nsamples = 17\nvalue = [12, 5]'),
#  Text(0.048198636806231744, 0.7727272727272727, 'Partner_encode <= 0.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.047224926971762414, 0.7424242424242424, 'gender_encode <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.046251217137293084, 0.7121212121212122, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.048198636806231744, 0.7121212121212122, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.049172346640701074, 0.7424242424242424, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.05209347614410906, 0.7727272727272727, 'TotalCharges <= 36.15\ngini = 0.165\nsamples = 11\nvalue = [10, 1]'),
#  Text(0.05111976630963973, 0.7424242424242424, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.05306718597857838, 0.7424242424242424, 'TotalCharges <= 39.275\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.05209347614410906, 0.7121212121212122, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05404089581304771, 0.7121212121212122, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.0942064264849075, 0.8636363636363636, 'SeniorCitizen <= 0.5\ngini = 0.492\nsamples = 255\nvalue = [111, 144]'),
#  Text(0.07716650438169426, 0.8333333333333334, 'PaperlessBilling_encode <= 0.5\ngini = 0.499\nsamples = 221\nvalue = [105, 116]'),
#  Text(0.06414313534566699, 0.803030303030303, 'MonthlyCharges <= 61.6\ngini = 0.49\nsamples = 100\nvalue = [57, 43]'),
#  Text(0.06316942551119767, 0.7727272727272727, 'TotalCharges <= 100.4\ngini = 0.485\nsamples = 97\nvalue = [57, 40]'),
#  Text(0.06219571567672833, 0.7424242424242424, 'TotalCharges <= 50.3\ngini = 0.495\nsamples = 89\nvalue = [49, 40]'),
#  Text(0.05598831548198637, 0.7121212121212122, 'TotalCharges <= 46.35\ngini = 0.473\nsamples = 60\nvalue = [37, 23]'),
#  Text(0.05501460564751704, 0.6818181818181818, 'MonthlyCharges <= 45.675\ngini = 0.493\nsamples = 52\nvalue = [29, 23]'),
#  Text(0.05404089581304771, 0.6515151515151515, 'TotalCharges <= 25.225\ngini = 0.466\nsamples = 46\nvalue = [29, 17]'),
#  Text(0.05038948393378773, 0.6212121212121212, 'MonthlyCharges <= 24.725\ngini = 0.497\nsamples = 13\nvalue = [6, 7]'),
#  Text(0.0494157740993184, 0.5909090909090909, 'TotalCharges <= 21.025\ngini = 0.48\nsamples = 10\nvalue = [6, 4]'),
#  Text(0.04746835443037975, 0.5606060606060606, 'gender_encode <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.04649464459591042, 0.5303030303030303, 'TotalCharges <= 20.925\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.04552093476144109, 0.5, 'gini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.04746835443037975, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.04844206426484907, 0.5303030303030303, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.05136319376825706, 0.5606060606060606, 'TotalCharges <= 24.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.05038948393378773, 0.5303030303030303, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.05233690360272639, 0.5303030303030303, 'Dependents_encode <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.05136319376825706, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.05331061343719572, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.05136319376825706, 0.5909090909090909, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.057692307692307696, 0.6212121212121212, 'MonthlyCharges <= 29.925\ngini = 0.422\nsamples = 33\nvalue = [23, 10]'),
#  Text(0.056718597857838365, 0.5909090909090909, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.05866601752677702, 0.5909090909090909, 'TotalCharges <= 30.375\ngini = 0.48\nsamples = 25\nvalue = [15, 10]'),
#  Text(0.057692307692307696, 0.5606060606060606, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.05963972736124635, 0.5606060606060606, 'Partner_encode <= 0.5\ngini = 0.454\nsamples = 23\nvalue = [15, 8]'),
#  Text(0.05720545277507303, 0.5303030303030303, 'TotalCharges <= 44.275\ngini = 0.42\nsamples = 20\nvalue = [14, 6]'),
#  Text(0.05525803310613437, 0.5, 'MonthlyCharges <= 39.85\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.05428432327166505, 0.4696969696969697, 'MonthlyCharges <= 34.75\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.05331061343719572, 0.4393939393939394, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.05525803310613437, 0.4393939393939394, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0562317429406037, 0.4696969696969697, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.059152872444011684, 0.5, 'TotalCharges <= 44.425\ngini = 0.486\nsamples = 12\nvalue = [7, 5]'),
#  Text(0.058179162609542354, 0.4696969696969697, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.060126582278481014, 0.4696969696969697, 'MonthlyCharges <= 44.9\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.059152872444011684, 0.4393939393939394, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.061100292112950344, 0.4393939393939394, 'MonthlyCharges <= 45.325\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.060126582278481014, 0.4090909090909091, 'gender_encode <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.059152872444011684, 0.3787878787878788, 'MonthlyCharges <= 45.225\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.058179162609542354, 0.3484848484848485, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.060126582278481014, 0.3484848484848485, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.061100292112950344, 0.3787878787878788, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.06207400194741967, 0.4090909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.06207400194741967, 0.5303030303030303, 'MonthlyCharges <= 42.325\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.061100292112950344, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06304771178188899, 0.5, 'Dependents_encode <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.06207400194741967, 0.4696969696969697, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06402142161635832, 0.4696969696969697, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.05598831548198637, 0.6515151515151515, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.056962025316455694, 0.6818181818181818, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.0684031158714703, 0.7121212121212122, 'MonthlyCharges <= 51.05\ngini = 0.485\nsamples = 29\nvalue = [12, 17]'),
#  Text(0.06256085686465433, 0.6818181818181818, 'MonthlyCharges <= 27.35\ngini = 0.375\nsamples = 16\nvalue = [4, 12]'),
#  Text(0.061587147030185, 0.6515151515151515, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.06353456669912366, 0.6515151515151515, 'TotalCharges <= 81.975\ngini = 0.32\nsamples = 15\nvalue = [3, 12]'),
#  Text(0.061587147030185, 0.6212121212121212, 'MonthlyCharges <= 50.7\ngini = 0.165\nsamples = 11\nvalue = [1, 10]'),
#  Text(0.06061343719571568, 0.5909090909090909, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.06256085686465433, 0.5909090909090909, 'TotalCharges <= 50.775\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.061587147030185, 0.5606060606060606, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.06353456669912366, 0.5606060606060606, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.06548198636806232, 0.6212121212121212, 'PhoneService_encode <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.06450827653359299, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.06645569620253164, 0.5909090909090909, 'gender_encode <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.06548198636806232, 0.5606060606060606, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.06742940603700097, 0.5606060606060606, 'TotalCharges <= 93.25\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.06645569620253164, 0.5303030303030303, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0684031158714703, 0.5303030303030303, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07424537487828627, 0.6818181818181818, 'MonthlyCharges <= 57.45\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.07229795520934762, 0.6515151515151515, 'Dependents_encode <= 0.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.07132424537487829, 0.6212121212121212, 'gender_encode <= 0.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.07035053554040896, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07229795520934762, 0.5909090909090909, 'TotalCharges <= 54.7\ngini = 0.408\nsamples = 7\nvalue = [5, 2]'),
#  Text(0.07132424537487829, 0.5606060606060606, 'TotalCharges <= 54.325\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.07035053554040896, 0.5303030303030303, 'TotalCharges <= 52.775\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.06937682570593963, 0.5, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.07132424537487829, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.07229795520934762, 0.5303030303030303, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.07327166504381694, 0.5606060606060606, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.07327166504381694, 0.6212121212121212, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.07619279454722493, 0.6515151515151515, 'MonthlyCharges <= 60.625\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.0752190847127556, 0.6212121212121212, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.07716650438169426, 0.6212121212121212, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.06414313534566699, 0.7424242424242424, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.06511684518013632, 0.7727272727272727, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.09018987341772151, 0.803030303030303, 'PhoneService_encode <= 0.5\ngini = 0.479\nsamples = 121\nvalue = [48, 73]'),
#  Text(0.08495618305744888, 0.7727272727272727, 'MonthlyCharges <= 30.575\ngini = 0.287\nsamples = 23\nvalue = [4, 19]'),
#  Text(0.08398247322297955, 0.7424242424242424, 'MonthlyCharges <= 27.5\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.08300876338851022, 0.7121212121212122, 'MonthlyCharges <= 25.125\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.08106134371957156, 0.6818181818181818, 'TotalCharges <= 24.425\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.08008763388510223, 0.6515151515151515, 'MonthlyCharges <= 24.325\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.07911392405063292, 0.6212121212121212, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08106134371957156, 0.6212121212121212, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.0820350535540409, 0.6515151515151515, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.08495618305744888, 0.6818181818181818, 'gender_encode <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.08398247322297955, 0.6515151515151515, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08592989289191821, 0.6515151515151515, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08495618305744888, 0.7121212121212122, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.08592989289191821, 0.7424242424242424, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.09542356377799416, 0.7727272727272727, 'MonthlyCharges <= 65.975\ngini = 0.495\nsamples = 98\nvalue = [44, 54]'),
#  Text(0.09444985394352483, 0.7424242424242424, 'MonthlyCharges <= 60.675\ngini = 0.499\nsamples = 93\nvalue = [44, 49]'),
#  Text(0.0934761441090555, 0.7121212121212122, 'TotalCharges <= 45.025\ngini = 0.495\nsamples = 89\nvalue = [40, 49]'),
#  Text(0.08885102239532619, 0.6818181818181818, 'MonthlyCharges <= 44.5\ngini = 0.465\nsamples = 19\nvalue = [12, 7]'),
#  Text(0.08787731256085686, 0.6515151515151515, 'MonthlyCharges <= 44.075\ngini = 0.497\nsamples = 13\nvalue = [6, 7]'),
#  Text(0.08690360272638753, 0.6212121212121212, 'TotalCharges <= 21.025\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.08592989289191821, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08787731256085686, 0.5909090909090909, 'TotalCharges <= 43.375\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.08690360272638753, 0.5606060606060606, 'TotalCharges <= 34.325\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.08592989289191821, 0.5303030303030303, 'TotalCharges <= 24.525\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.08495618305744888, 0.5, 'Dependents_encode <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.08398247322297955, 0.4696969696969697, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08592989289191821, 0.4696969696969697, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08690360272638753, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.08787731256085686, 0.5303030303030303, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.08885102239532619, 0.5606060606060606, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.08885102239532619, 0.6212121212121212, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.08982473222979552, 0.6515151515151515, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.0981012658227848, 0.6818181818181818, 'TotalCharges <= 45.75\ngini = 0.48\nsamples = 70\nvalue = [28, 42]'),
#  Text(0.09177215189873418, 0.6515151515151515, 'TotalCharges <= 45.575\ngini = 0.278\nsamples = 12\nvalue = [2, 10]'),
#  Text(0.09079844206426485, 0.6212121212121212, 'MonthlyCharges <= 45.35\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.08982473222979552, 0.5909090909090909, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.09177215189873418, 0.5909090909090909, 'TotalCharges <= 45.475\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.09079844206426485, 0.5606060606060606, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.09274586173320351, 0.5606060606060606, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09274586173320351, 0.6212121212121212, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.10443037974683544, 0.6515151515151515, 'Dependents_encode <= 0.5\ngini = 0.495\nsamples = 58\nvalue = [26, 32]'),
#  Text(0.10053554040895812, 0.6212121212121212, 'MonthlyCharges <= 50.375\ngini = 0.482\nsamples = 52\nvalue = [21, 31]'),
#  Text(0.09566699123661149, 0.5909090909090909, 'MonthlyCharges <= 50.125\ngini = 0.5\nsamples = 28\nvalue = [14, 14]'),
#  Text(0.09469328140214216, 0.5606060606060606, 'TotalCharges <= 90.425\ngini = 0.486\nsamples = 24\nvalue = [10, 14]'),
#  Text(0.09274586173320351, 0.5303030303030303, 'TotalCharges <= 86.2\ngini = 0.498\nsamples = 17\nvalue = [9, 8]'),
#  Text(0.09177215189873418, 0.5, 'TotalCharges <= 45.825\ngini = 0.498\nsamples = 15\nvalue = [7, 8]'),
#  Text(0.09079844206426485, 0.4696969696969697, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09274586173320351, 0.4696969696969697, 'MonthlyCharges <= 48.95\ngini = 0.49\nsamples = 14\nvalue = [6, 8]'),
#  Text(0.09031158714703018, 0.4393939393939394, 'gender_encode <= 0.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.08933787731256086, 0.4090909090909091, 'Partner_encode <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.08836416747809153, 0.3787878787878788, 'MonthlyCharges <= 48.525\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.0873904576436222, 0.3484848484848485, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.08933787731256086, 0.3484848484848485, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09031158714703018, 0.3787878787878788, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.09128529698149951, 0.4090909090909091, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.09518013631937683, 0.4393939393939394, 'TotalCharges <= 49.925\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.09323271665043817, 0.4090909090909091, 'TotalCharges <= 49.725\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.09225900681596884, 0.3787878787878788, 'TotalCharges <= 49.475\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.09128529698149951, 0.3484848484848485, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09323271665043817, 0.3484848484848485, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0942064264849075, 0.3787878787878788, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.09712755598831548, 0.4090909090909091, 'MonthlyCharges <= 50.025\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.09615384615384616, 0.3787878787878788, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0981012658227848, 0.3787878787878788, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.09371957156767283, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.09664070107108082, 0.5303030303030303, 'TotalCharges <= 102.05\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.09566699123661149, 0.5, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.09761441090555015, 0.5, 'TotalCharges <= 106.075\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.09664070107108082, 0.4696969696969697, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.09858812074001948, 0.4696969696969697, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.09664070107108082, 0.5606060606060606, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.10540408958130477, 0.5909090909090909, 'TotalCharges <= 114.125\ngini = 0.413\nsamples = 24\nvalue = [7, 17]'),
#  Text(0.10443037974683544, 0.5606060606060606, 'Partner_encode <= 0.5\ngini = 0.351\nsamples = 22\nvalue = [5, 17]'),
#  Text(0.10345666991236611, 0.5303030303030303, 'TotalCharges <= 55.125\ngini = 0.308\nsamples = 21\nvalue = [4, 17]'),
#  Text(0.10150925024342745, 0.5, 'TotalCharges <= 50.775\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(0.10053554040895812, 0.4696969696969697, 'MonthlyCharges <= 50.6\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.09956183057448881, 0.4393939393939394, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.10150925024342745, 0.4393939393939394, 'gini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.10248296007789678, 0.4696969696969697, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.10540408958130477, 0.5, 'TotalCharges <= 55.575\ngini = 0.444\nsamples = 9\nvalue = [3, 6]'),
#  Text(0.10443037974683544, 0.4696969696969697, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1063777994157741, 0.4696969696969697, 'MonthlyCharges <= 54.75\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.10540408958130477, 0.4393939393939394, 'MonthlyCharges <= 54.425\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.10443037974683544, 0.4090909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1063777994157741, 0.4090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.10735150925024342, 0.4393939393939394, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.10540408958130477, 0.5303030303030303, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1063777994157741, 0.5606060606060606, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.10832521908471275, 0.6212121212121212, 'MonthlyCharges <= 47.3\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.10735150925024342, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.10929892891918208, 0.5909090909090909, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.09542356377799416, 0.7121212121212122, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.09639727361246349, 0.7424242424242424, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.11124634858812074, 0.8333333333333334, 'MonthlyCharges <= 43.65\ngini = 0.291\nsamples = 34\nvalue = [6, 28]'),
#  Text(0.11027263875365141, 0.803030303030303, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.11222005842259007, 0.803030303030303, 'MonthlyCharges <= 50.05\ngini = 0.408\nsamples = 21\nvalue = [6, 15]'),
#  Text(0.11124634858812074, 0.7727272727272727, 'Partner_encode <= 0.5\ngini = 0.49\nsamples = 14\nvalue = [6, 8]'),
#  Text(0.11027263875365141, 0.7424242424242424, 'MonthlyCharges <= 45.15\ngini = 0.5\nsamples = 12\nvalue = [6, 6]'),
#  Text(0.10832521908471275, 0.7121212121212122, 'MonthlyCharges <= 44.5\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.10735150925024342, 0.6818181818181818, 'TotalCharges <= 90.975\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.1063777994157741, 0.6515151515151515, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.10832521908471275, 0.6515151515151515, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.10929892891918208, 0.6818181818181818, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.11222005842259007, 0.7121212121212122, 'PaperlessBilling_encode <= 0.5\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.11124634858812074, 0.6818181818181818, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.1131937682570594, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11222005842259007, 0.7424242424242424, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1131937682570594, 0.7727272727272727, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.17243697510954237, 0.8939393939393939, 'MonthlyCharges <= 27.425\ngini = 0.328\nsamples = 721\nvalue = [572, 149]'),
#  Text(0.12340250730282376, 0.8636363636363636, 'PhoneService_encode <= 0.5\ngini = 0.209\nsamples = 321\nvalue = [283, 38]'),
#  Text(0.11611489776046738, 0.8333333333333334, 'MonthlyCharges <= 24.275\ngini = 0.488\nsamples = 19\nvalue = [11, 8]'),
#  Text(0.11514118792599805, 0.803030303030303, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.11708860759493671, 0.803030303030303, 'TotalCharges <= 72.6\ngini = 0.43\nsamples = 16\nvalue = [11, 5]'),
#  Text(0.11611489776046738, 0.7727272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.11806231742940604, 0.7727272727272727, 'MonthlyCharges <= 25.375\ngini = 0.337\nsamples = 14\nvalue = [11, 3]'),
#  Text(0.11708860759493671, 0.7424242424242424, 'TotalCharges <= 112.95\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(0.11611489776046738, 0.7121212121212122, 'PaperlessBilling_encode <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.11514118792599805, 0.6818181818181818, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.11708860759493671, 0.6818181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.11806231742940604, 0.7121212121212122, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.11903602726387537, 0.7424242424242424, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13069011684518014, 0.8333333333333334, 'TotalCharges <= 397.225\ngini = 0.179\nsamples = 302\nvalue = [272, 30]'),
#  Text(0.1297164070107108, 0.803030303030303, 'TotalCharges <= 60.2\ngini = 0.174\nsamples = 301\nvalue = [272, 29]'),
#  Text(0.12195715676728335, 0.7727272727272727, 'TotalCharges <= 58.575\ngini = 0.426\nsamples = 13\nvalue = [9, 4]'),
#  Text(0.12098344693281401, 0.7424242424242424, 'gender_encode <= 0.5\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.1200097370983447, 0.7121212121212122, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.12195715676728335, 0.7121212121212122, 'PaperlessBilling_encode <= 0.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.12098344693281401, 0.6818181818181818, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.12293086660175268, 0.6818181818181818, 'tenure <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.12195715676728335, 0.6515151515151515, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.123904576436222, 0.6515151515151515, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.12293086660175268, 0.7424242424242424, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.13747565725413827, 0.7727272727272727, 'MonthlyCharges <= 19.275\ngini = 0.159\nsamples = 288\nvalue = [263, 25]'),
#  Text(0.1277994157740993, 0.7424242424242424, 'MonthlyCharges <= 19.225\ngini = 0.36\nsamples = 17\nvalue = [13, 4]'),
#  Text(0.12585199610516065, 0.7121212121212122, 'TotalCharges <= 174.4\ngini = 0.245\nsamples = 14\nvalue = [12, 2]'),
#  Text(0.12487828627069134, 0.6818181818181818, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.12682570593963, 0.6818181818181818, 'tenure <= 13.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.12585199610516065, 0.6515151515151515, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1277994157740993, 0.6515151515151515, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.12974683544303797, 0.7121212121212122, 'TotalCharges <= 99.175\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.12877312560856866, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.13072054527750732, 0.6818181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.14715189873417722, 0.7424242424242424, 'MonthlyCharges <= 20.375\ngini = 0.143\nsamples = 271\nvalue = [250, 21]'),
#  Text(0.14118792599805258, 0.7121212121212122, 'gender_encode <= 0.5\ngini = 0.181\nsamples = 179\nvalue = [161, 18]'),
#  Text(0.1336416747809153, 0.6818181818181818, 'TotalCharges <= 167.875\ngini = 0.254\nsamples = 94\nvalue = [80, 14]'),
#  Text(0.12974683544303797, 0.6515151515151515, 'TotalCharges <= 144.975\ngini = 0.363\nsamples = 42\nvalue = [32, 10]'),
#  Text(0.1277994157740993, 0.6212121212121212, 'MonthlyCharges <= 20.3\ngini = 0.251\nsamples = 34\nvalue = [29, 5]'),
#  Text(0.12682570593963, 0.5909090909090909, 'MonthlyCharges <= 19.775\ngini = 0.17\nsamples = 32\nvalue = [29, 3]'),
#  Text(0.12585199610516065, 0.5606060606060606, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(0.1277994157740993, 0.5606060606060606, 'MonthlyCharges <= 19.9\ngini = 0.245\nsamples = 21\nvalue = [18, 3]'),
#  Text(0.12585199610516065, 0.5303030303030303, 'Partner_encode <= 0.5\ngini = 0.5\nsamples = 4\nvalue = [2, 2]'),
#  Text(0.12487828627069134, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.12682570593963, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.12974683544303797, 0.5303030303030303, 'TotalCharges <= 127.775\ngini = 0.111\nsamples = 17\nvalue = [16, 1]'),
#  Text(0.12877312560856866, 0.5, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.13072054527750732, 0.5, 'tenure <= 7.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.12974683544303797, 0.4696969696969697, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13169425511197663, 0.4696969696969697, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.12877312560856866, 0.5909090909090909, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.13169425511197663, 0.6212121212121212, 'MonthlyCharges <= 19.775\ngini = 0.469\nsamples = 8\nvalue = [3, 5]'),
#  Text(0.13072054527750732, 0.5909090909090909, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.13266796494644595, 0.5909090909090909, 'MonthlyCharges <= 19.95\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.13169425511197663, 0.5606060606060606, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1336416747809153, 0.5606060606060606, 'TotalCharges <= 153.425\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.13266796494644595, 0.5303030303030303, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1346153846153846, 0.5303030303030303, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1375365141187926, 0.6515151515151515, 'TotalCharges <= 221.075\ngini = 0.142\nsamples = 52\nvalue = [48, 4]'),
#  Text(0.13656280428432327, 0.6212121212121212, 'gini = 0.0\nsamples = 19\nvalue = [19, 0]'),
#  Text(0.13851022395326193, 0.6212121212121212, 'TotalCharges <= 222.475\ngini = 0.213\nsamples = 33\nvalue = [29, 4]'),
#  Text(0.1375365141187926, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.13948393378773125, 0.5909090909090909, 'MonthlyCharges <= 19.85\ngini = 0.17\nsamples = 32\nvalue = [29, 3]'),
#  Text(0.13851022395326193, 0.5606060606060606, 'MonthlyCharges <= 19.725\ngini = 0.266\nsamples = 19\nvalue = [16, 3]'),
#  Text(0.13656280428432327, 0.5303030303030303, 'MonthlyCharges <= 19.425\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(0.13558909444985395, 0.5, 'MonthlyCharges <= 19.375\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.1346153846153846, 0.4696969696969697, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.13656280428432327, 0.4696969696969697, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1375365141187926, 0.5, 'gini = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(0.1404576436222006, 0.5303030303030303, 'Partner_encode <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.13948393378773125, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1414313534566699, 0.5, 'tenure <= 13.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.1404576436222006, 0.4696969696969697, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14240506329113925, 0.4696969696969697, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1404576436222006, 0.5606060606060606, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.14873417721518986, 0.6818181818181818, 'TotalCharges <= 341.875\ngini = 0.09\nsamples = 85\nvalue = [81, 4]'),
#  Text(0.14776046738072054, 0.6515151515151515, 'SeniorCitizen <= 0.5\ngini = 0.069\nsamples = 84\nvalue = [81, 3]'),
#  Text(0.14532619279454723, 0.6212121212121212, 'TotalCharges <= 286.2\ngini = 0.049\nsamples = 80\nvalue = [78, 2]'),
#  Text(0.14337877312560857, 0.5909090909090909, 'MonthlyCharges <= 20.225\ngini = 0.027\nsamples = 73\nvalue = [72, 1]'),
#  Text(0.14240506329113925, 0.5606060606060606, 'gini = 0.0\nsamples = 61\nvalue = [61, 0]'),
#  Text(0.1443524829600779, 0.5606060606060606, 'tenure <= 8.5\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.14337877312560857, 0.5303030303030303, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.14532619279454723, 0.5303030303030303, 'tenure <= 9.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.1443524829600779, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.14629990262901654, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.1472736124634859, 0.5909090909090909, 'TotalCharges <= 294.225\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.14629990262901654, 0.5606060606060606, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1482473222979552, 0.5606060606060606, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.15019474196689386, 0.6212121212121212, 'TotalCharges <= 198.95\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.14922103213242455, 0.5909090909090909, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.1511684518013632, 0.5909090909090909, 'MonthlyCharges <= 19.8\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.15019474196689386, 0.5606060606060606, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.15214216163583252, 0.5606060606060606, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1497078870496592, 0.6515151515151515, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15311587147030184, 0.7121212121212122, 'MonthlyCharges <= 20.925\ngini = 0.063\nsamples = 92\nvalue = [89, 3]'),
#  Text(0.15214216163583252, 0.6818181818181818, 'gini = 0.0\nsamples = 49\nvalue = [49, 0]'),
#  Text(0.15408958130477118, 0.6818181818181818, 'MonthlyCharges <= 23.375\ngini = 0.13\nsamples = 43\nvalue = [40, 3]'),
#  Text(0.15311587147030184, 0.6515151515151515, 'tenure <= 5.5\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.15214216163583252, 0.6212121212121212, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.15408958130477118, 0.6212121212121212, 'MonthlyCharges <= 22.2\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.15311587147030184, 0.5909090909090909, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.1550632911392405, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1550632911392405, 0.6515151515151515, 'gini = 0.0\nsamples = 34\nvalue = [34, 0]'),
#  Text(0.13166382667964946, 0.803030303030303, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.22147144291626095, 0.8636363636363636, 'TotalCharges <= 332.475\ngini = 0.401\nsamples = 400\nvalue = [289, 111]'),
#  Text(0.19344115141187926, 0.8333333333333334, 'MonthlyCharges <= 55.425\ngini = 0.476\nsamples = 174\nvalue = [106, 68]'),
#  Text(0.18337694741966895, 0.803030303030303, 'tenure <= 8.5\ngini = 0.493\nsamples = 143\nvalue = [80, 63]'),
#  Text(0.17055136319376826, 0.7727272727272727, 'MonthlyCharges <= 30.425\ngini = 0.485\nsamples = 133\nvalue = [78, 55]'),
#  Text(0.15749756572541382, 0.7424242424242424, 'MonthlyCharges <= 28.825\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(0.1565238558909445, 0.7121212121212122, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15847127555988316, 0.7121212121212122, 'TotalCharges <= 221.175\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.15749756572541382, 0.6818181818181818, 'gini = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(0.15944498539435248, 0.6818181818181818, 'gender_encode <= 0.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.15847127555988316, 0.6515151515151515, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16041869522882182, 0.6515151515151515, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.18360516066212268, 0.7424242424242424, 'TotalCharges <= 310.475\ngini = 0.493\nsamples = 120\nvalue = [67, 53]'),
#  Text(0.17685004868549173, 0.7121212121212122, 'PaperlessBilling_encode <= 0.5\ngini = 0.498\nsamples = 111\nvalue = [59, 52]'),
#  Text(0.16626095423563778, 0.6818181818181818, 'MonthlyCharges <= 45.575\ngini = 0.481\nsamples = 57\nvalue = [34, 23]'),
#  Text(0.16236611489776046, 0.6515151515151515, 'Partner_encode <= 0.5\ngini = 0.375\nsamples = 28\nvalue = [21, 7]'),
#  Text(0.15895813047711782, 0.6212121212121212, 'MonthlyCharges <= 40.675\ngini = 0.469\nsamples = 16\nvalue = [10, 6]'),
#  Text(0.15701071080817916, 0.5909090909090909, 'TotalCharges <= 137.55\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.15603700097370984, 0.5606060606060606, 'MonthlyCharges <= 35.1\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.1550632911392405, 0.5303030303030303, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.15701071080817916, 0.5303030303030303, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1579844206426485, 0.5606060606060606, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.16090555014605648, 0.5909090909090909, 'MonthlyCharges <= 44.65\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.15993184031158714, 0.5606060606060606, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.1618792599805258, 0.5606060606060606, 'TotalCharges <= 134.4\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.16090555014605648, 0.5303030303030303, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16285296981499514, 0.5303030303030303, 'MonthlyCharges <= 44.875\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.1618792599805258, 0.5, 'TotalCharges <= 209.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.16090555014605648, 0.4696969696969697, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16285296981499514, 0.4696969696969697, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16382667964946446, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.16577409931840312, 0.6212121212121212, 'TotalCharges <= 144.925\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(0.1648003894839338, 0.5909090909090909, 'PhoneService_encode <= 0.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.16382667964946446, 0.5606060606060606, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.16577409931840312, 0.5606060606060606, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.16674780915287243, 0.5909090909090909, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.1701557935735151, 0.6515151515151515, 'MonthlyCharges <= 47.7\ngini = 0.495\nsamples = 29\nvalue = [13, 16]'),
#  Text(0.16918208373904575, 0.6212121212121212, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.1711295034079844, 0.6212121212121212, 'TotalCharges <= 179.6\ngini = 0.497\nsamples = 24\nvalue = [13, 11]'),
#  Text(0.1686952288218111, 0.5909090909090909, 'TotalCharges <= 144.275\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.16772151898734178, 0.5606060606060606, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.16966893865628044, 0.5606060606060606, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.17356377799415773, 0.5909090909090909, 'gender_encode <= 0.5\ngini = 0.465\nsamples = 19\nvalue = [12, 7]'),
#  Text(0.1716163583252191, 0.5606060606060606, 'TotalCharges <= 307.925\ngini = 0.32\nsamples = 10\nvalue = [8, 2]'),
#  Text(0.17064264849074975, 0.5303030303030303, 'Dependents_encode <= 0.5\ngini = 0.198\nsamples = 9\nvalue = [8, 1]'),
#  Text(0.16966893865628044, 0.5, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.1716163583252191, 0.5, 'MonthlyCharges <= 50.575\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.17064264849074975, 0.4696969696969697, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.17259006815968841, 0.4696969696969697, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.17259006815968841, 0.5303030303030303, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1755111976630964, 0.5606060606060606, 'tenure <= 5.5\ngini = 0.494\nsamples = 9\nvalue = [4, 5]'),
#  Text(0.17453748782862707, 0.5303030303030303, 'MonthlyCharges <= 49.3\ngini = 0.408\nsamples = 7\nvalue = [2, 5]'),
#  Text(0.17356377799415773, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1755111976630964, 0.5, 'MonthlyCharges <= 54.025\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.17453748782862707, 0.4696969696969697, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.17648490749756574, 0.4696969696969697, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.17648490749756574, 0.5303030303030303, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
# ...
#  Text(0.3384858812074002, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3394595910418695, 0.6212121212121212, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.3423807205452775, 0.6515151515151515, 'gender_encode <= 0.5\ngini = 0.49\nsamples = 7\nvalue = [4, 3]'),
#  Text(0.3414070107108082, 0.6212121212121212, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.34335443037974683, 0.6212121212121212, 'TotalCharges <= 212.55\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.3423807205452775, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.34432814021421615, 0.5909090909090909, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.34530185004868547, 0.6818181818181818, 'MonthlyCharges <= 77.15\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.34432814021421615, 0.6515151515151515, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.34627555988315484, 0.6515151515151515, 'MonthlyCharges <= 80.225\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.34530185004868547, 0.6212121212121212, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.34724926971762415, 0.6212121212121212, 'MonthlyCharges <= 85.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.34627555988315484, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.34822297955209347, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3448149951314508, 0.7121212121212122, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3477361246348588, 0.7424242424242424, 'Dependents_encode <= 0.5\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.3467624148003895, 0.7121212121212122, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.34870983446932813, 0.7121212121212122, 'tenure <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.3477361246348588, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.34968354430379744, 0.6818181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.35260467380720545, 0.7727272727272727, 'MonthlyCharges <= 104.7\ngini = 0.34\nsamples = 23\nvalue = [5, 18]'),
#  Text(0.35163096397273613, 0.7424242424242424, 'tenure <= 6.5\ngini = 0.298\nsamples = 22\nvalue = [4, 18]'),
#  Text(0.3506572541382668, 0.7121212121212122, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.35260467380720545, 0.7121212121212122, 'MonthlyCharges <= 75.525\ngini = 0.375\nsamples = 16\nvalue = [4, 12]'),
#  Text(0.35163096397273613, 0.6818181818181818, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.35357838364167476, 0.6818181818181818, 'TotalCharges <= 647.6\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.35163096397273613, 0.6515151515151515, 'SeniorCitizen <= 0.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.3506572541382668, 0.6212121212121212, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.35260467380720545, 0.6212121212121212, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.35552580331061345, 0.6515151515151515, 'SeniorCitizen <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [1, 6]'),
#  Text(0.35455209347614414, 0.6212121212121212, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.35649951314508277, 0.6212121212121212, 'MonthlyCharges <= 92.75\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.35552580331061345, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3574732229795521, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.35357838364167476, 0.7424242424242424, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3667234664070107, 0.803030303030303, 'Dependents_encode <= 0.5\ngini = 0.469\nsamples = 56\nvalue = [35, 21]'),
#  Text(0.36331548198636804, 0.7727272727272727, 'MonthlyCharges <= 85.175\ngini = 0.498\nsamples = 43\nvalue = [23, 20]'),
#  Text(0.3594206426484908, 0.7424242424242424, 'tenure <= 10.5\ngini = 0.363\nsamples = 21\nvalue = [16, 5]'),
#  Text(0.3584469328140214, 0.7121212121212122, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.3603943524829601, 0.7121212121212122, 'TotalCharges <= 821.275\ngini = 0.43\nsamples = 16\nvalue = [11, 5]'),
#  Text(0.3594206426484908, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3613680623174294, 0.6818181818181818, 'tenure <= 11.5\ngini = 0.391\nsamples = 15\nvalue = [11, 4]'),
#  Text(0.3603943524829601, 0.6515151515151515, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.3623417721518987, 0.6515151515151515, 'TotalCharges <= 1034.875\ngini = 0.444\nsamples = 12\nvalue = [8, 4]'),
#  Text(0.3603943524829601, 0.6212121212121212, 'TotalCharges <= 912.025\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.3594206426484908, 0.5909090909090909, 'MonthlyCharges <= 80.275\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.3584469328140214, 0.5606060606060606, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3603943524829601, 0.5606060606060606, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3613680623174294, 0.5909090909090909, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.3642891918208374, 0.6212121212121212, 'SeniorCitizen <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.36331548198636804, 0.5909090909090909, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.3652629016553067, 0.5909090909090909, 'tenure <= 14.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3642891918208374, 0.5606060606060606, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.36623661148977604, 0.5606060606060606, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.36721032132424536, 0.7424242424242424, 'TotalCharges <= 1144.35\ngini = 0.434\nsamples = 22\nvalue = [7, 15]'),
#  Text(0.36623661148977604, 0.7121212121212122, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.36818403115871473, 0.7121212121212122, 'MonthlyCharges <= 90.575\ngini = 0.497\nsamples = 13\nvalue = [7, 6]'),
#  Text(0.36623661148977604, 0.6818181818181818, 'TotalCharges <= 1279.25\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.3652629016553067, 0.6515151515151515, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.36721032132424536, 0.6515151515151515, 'TotalCharges <= 1339.45\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.36623661148977604, 0.6212121212121212, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.36818403115871473, 0.6212121212121212, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.37013145082765336, 0.6818181818181818, 'MonthlyCharges <= 96.925\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.36915774099318405, 0.6515151515151515, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.3711051606621227, 0.6515151515151515, 'TotalCharges <= 1626.075\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.37013145082765336, 0.6212121212121212, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.372078870496592, 0.6212121212121212, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.37013145082765336, 0.7727272727272727, 'TotalCharges <= 1192.275\ngini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(0.36915774099318405, 0.7424242424242424, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.3711051606621227, 0.7424242424242424, 'TotalCharges <= 1310.525\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.37013145082765336, 0.7121212121212122, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.372078870496592, 0.7121212121212122, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.43339976874391434, 0.8333333333333334, 'MonthlyCharges <= 84.375\ngini = 0.436\nsamples = 492\nvalue = [158, 334]'),
#  Text(0.39849074975657256, 0.803030303030303, 'TotalCharges <= 416.65\ngini = 0.482\nsamples = 230\nvalue = [93, 137]'),
#  Text(0.3870496592015579, 0.7727272727272727, 'MonthlyCharges <= 82.15\ngini = 0.425\nsamples = 88\nvalue = [27, 61]'),
#  Text(0.3825462512171373, 0.7424242424242424, 'MonthlyCharges <= 79.925\ngini = 0.384\nsamples = 81\nvalue = [21, 60]'),
#  Text(0.377921129503408, 0.7121212121212122, 'MonthlyCharges <= 75.675\ngini = 0.302\nsamples = 54\nvalue = [10, 44]'),
#  Text(0.3759737098344693, 0.6818181818181818, 'MonthlyCharges <= 75.6\ngini = 0.444\nsamples = 27\nvalue = [9, 18]'),
#  Text(0.375, 0.6515151515151515, 'TotalCharges <= 297.075\ngini = 0.403\nsamples = 25\nvalue = [7, 18]'),
#  Text(0.3740262901655307, 0.6212121212121212, 'TotalCharges <= 231.025\ngini = 0.475\nsamples = 18\nvalue = [7, 11]'),
#  Text(0.37159201557935734, 0.5909090909090909, 'TotalCharges <= 145.1\ngini = 0.375\nsamples = 12\nvalue = [3, 9]'),
#  Text(0.3696445959104187, 0.5606060606060606, 'TotalCharges <= 139.75\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.3686708860759494, 0.5303030303030303, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.370618305744888, 0.5303030303030303, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.373539435248296, 0.5606060606060606, 'TotalCharges <= 211.35\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.37256572541382665, 0.5303030303030303, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.37451314508276534, 0.5303030303030303, 'TotalCharges <= 216.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.373539435248296, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.37548685491723466, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.376460564751704, 0.5909090909090909, 'TotalCharges <= 257.4\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.37548685491723466, 0.5606060606060606, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.37743427458617335, 0.5606060606060606, 'TotalCharges <= 287.65\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.376460564751704, 0.5303030303030303, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.37840798442064266, 0.5303030303030303, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3759737098344693, 0.6212121212121212, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.37694741966893863, 0.6515151515151515, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.37986854917234664, 0.6818181818181818, 'TotalCharges <= 217.275\ngini = 0.071\nsamples = 27\nvalue = [1, 26]'),
#  Text(0.3788948393378773, 0.6515151515151515, 'TotalCharges <= 205.6\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.377921129503408, 0.6212121212121212, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.37986854917234664, 0.6212121212121212, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.38084225900681595, 0.6515151515151515, 'gini = 0.0\nsamples = 17\nvalue = [0, 17]'),
#  Text(0.3871713729308666, 0.7121212121212122, 'MonthlyCharges <= 80.55\ngini = 0.483\nsamples = 27\nvalue = [11, 16]'),
#  Text(0.3847370983446933, 0.6818181818181818, 'MonthlyCharges <= 80.175\ngini = 0.484\nsamples = 17\nvalue = [10, 7]'),
#  Text(0.38278967867575464, 0.6515151515151515, 'TotalCharges <= 374.325\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.38181596884128527, 0.6212121212121212, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.38376338851022396, 0.6212121212121212, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.38668451801363196, 0.6515151515151515, 'Partner_encode <= 0.5\ngini = 0.496\nsamples = 11\nvalue = [5, 6]'),
#  Text(0.3857108081791626, 0.6212121212121212, 'TotalCharges <= 206.725\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(0.3847370983446933, 0.5909090909090909, 'MonthlyCharges <= 80.35\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.38376338851022396, 0.5606060606060606, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3857108081791626, 0.5606060606060606, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.38668451801363196, 0.5909090909090909, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3876582278481013, 0.6212121212121212, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3896056475170399, 0.6818181818181818, 'Dependents_encode <= 0.5\ngini = 0.18\nsamples = 10\nvalue = [1, 9]'),
#  Text(0.3886319376825706, 0.6515151515151515, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.3905793573515092, 0.6515151515151515, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3915530671859786, 0.7424242424242424, 'Partner_encode <= 0.5\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.3905793573515092, 0.7121212121212122, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.3925267770204479, 0.7121212121212122, 'TotalCharges <= 200.725\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.3915530671859786, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.39350048685491723, 0.6818181818181818, 'MonthlyCharges <= 83.575\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.3925267770204479, 0.6515151515151515, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.39447419668938655, 0.6515151515151515, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.40993184031158714, 0.7727272727272727, 'MonthlyCharges <= 74.575\ngini = 0.498\nsamples = 142\nvalue = [66, 76]'),
#  Text(0.40031645569620256, 0.7424242424242424, 'MonthlyCharges <= 74.175\ngini = 0.413\nsamples = 24\nvalue = [7, 17]'),
#  Text(0.39836903602726387, 0.7121212121212122, 'SeniorCitizen <= 0.5\ngini = 0.494\nsamples = 9\nvalue = [5, 4]'),
#  Text(0.39739532619279455, 0.6818181818181818, 'tenure <= 11.5\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.39642161635832524, 0.6515151515151515, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.39836903602726387, 0.6515151515151515, 'tenure <= 14.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.39739532619279455, 0.6212121212121212, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3993427458617332, 0.6212121212121212, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3993427458617332, 0.6818181818181818, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4022638753651412, 0.7121212121212122, 'tenure <= 15.5\ngini = 0.231\nsamples = 15\nvalue = [2, 13]'),
#  Text(0.40129016553067187, 0.6818181818181818, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.4032375851996105, 0.6818181818181818, 'MonthlyCharges <= 74.375\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.4022638753651412, 0.6515151515151515, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4042112950340798, 0.6515151515151515, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.4195472249269718, 0.7424242424242424, 'MonthlyCharges <= 79.025\ngini = 0.5\nsamples = 118\nvalue = [59, 59]'),
#  Text(0.4122444011684518, 0.7121212121212122, 'MonthlyCharges <= 75.8\ngini = 0.469\nsamples = 48\nvalue = [30, 18]'),
#  Text(0.4071324245374878, 0.6818181818181818, 'tenure <= 6.5\ngini = 0.499\nsamples = 31\nvalue = [16, 15]'),
#  Text(0.4061587147030185, 0.6515151515151515, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.40810613437195714, 0.6515151515151515, 'TotalCharges <= 493.725\ngini = 0.495\nsamples = 29\nvalue = [16, 13]'),
#  Text(0.4071324245374878, 0.6212121212121212, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.40907984420642646, 0.6212121212121212, 'TotalCharges <= 523.05\ngini = 0.499\nsamples = 27\nvalue = [14, 13]'),
#  Text(0.40810613437195714, 0.5909090909090909, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.41005355404089583, 0.5909090909090909, 'TotalCharges <= 788.475\ngini = 0.493\nsamples = 25\nvalue = [14, 11]'),
#  Text(0.40664556962025317, 0.5606060606060606, 'MonthlyCharges <= 75.725\ngini = 0.444\nsamples = 15\nvalue = [10, 5]'),
#  Text(0.40469814995131453, 0.5303030303030303, 'MonthlyCharges <= 75.125\ngini = 0.375\nsamples = 12\nvalue = [9, 3]'),
#  Text(0.40372444011684516, 0.5, 'tenure <= 7.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.40275073028237585, 0.4696969696969697, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.40469814995131453, 0.4696969696969697, 'tenure <= 8.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.40372444011684516, 0.4393939393939394, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.40567185978578385, 0.4393939393939394, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.40567185978578385, 0.5, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.4085929892891918, 0.5303030303030303, 'tenure <= 9.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  ...]

# %%
# export_text 를 통해 문자( text )로 트리를 시각화 합니다.
# 너무 길어 한눈에 보기가 어려울 경우, max_depth 를 설정하면 특정 깊이까지만 보입니다.
from sklearn.tree import export_text
# 여기에 구현해 주세요.
tree_rules = export_text(model, feature_names=feature_names.tolist(), max_depth=10)

print(tree_rules)
# Out:
# |--- tenure <= 16.50
# |   |--- MonthlyCharges <= 69.22
# |   |   |--- tenure <= 2.50
# |   |   |   |--- MonthlyCharges <= 20.85
# |   |   |   |   |--- TotalCharges <= 20.27
# |   |   |   |   |   |--- TotalCharges <= 19.27
# |   |   |   |   |   |   |--- PaperlessBilling_encode <= 0.50
# |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |--- PaperlessBilling_encode >  0.50
# |   |   |   |   |   |   |   |--- MonthlyCharges <= 19.15
# |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 19.05
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- MonthlyCharges >  19.05
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- MonthlyCharges >  19.15
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |--- TotalCharges >  19.27
# |   |   |   |   |   |   |--- SeniorCitizen <= 0.50
# |   |   |   |   |   |   |   |--- MonthlyCharges <= 20.07
# |   |   |   |   |   |   |   |   |--- gender_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 19.35
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- TotalCharges >  19.35
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 19.43
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  19.43
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |--- gender_encode >  0.50
# |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 20.02
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 19.88
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  19.88
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- TotalCharges >  20.02
# |   |   |   |   |   |   |   |   |   |   |--- Dependents_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Dependents_encode >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- MonthlyCharges >  20.07
# |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 20.18
# |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 20.12
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- TotalCharges >  20.12
# |   |   |   |   |   |   |   |   |   |   |--- Dependents_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- Dependents_encode >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- MonthlyCharges >  20.18
# |   |   |   |   |   |   |   |   |   |--- PaperlessBilling_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 20.23
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  20.23
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- PaperlessBilling_encode >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- Dependents_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Dependents_encode >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |--- SeniorCitizen >  0.50
# |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |--- TotalCharges >  20.27
# |   |   |   |   |   |--- MonthlyCharges <= 20.48
# |   |   |   |   |   |   |--- MonthlyCharges <= 19.88
# |   |   |   |   |   |   |   |--- TotalCharges <= 36.55
# |   |   |   |   |   |   |   |   |--- TotalCharges <= 27.92
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- TotalCharges >  27.92
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- TotalCharges >  36.55
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |--- MonthlyCharges >  19.88
# |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |--- MonthlyCharges >  20.48
# |   |   |   |   |   |   |--- TotalCharges <= 20.57
# |   |   |   |   |   |   |   |--- Partner_encode <= 0.50
# |   |   |   |   |   |   |   |   |--- gender_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- gender_encode >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- Partner_encode >  0.50
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- TotalCharges >  20.57
# |   |   |   |   |   |   |   |--- TotalCharges <= 36.15
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- TotalCharges >  36.15
# |   |   |   |   |   |   |   |   |--- TotalCharges <= 39.27
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- TotalCharges >  39.27
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |--- MonthlyCharges >  20.85
# |   |   |   |   |--- SeniorCitizen <= 0.50
# |   |   |   |   |   |--- PaperlessBilling_encode <= 0.50
# |   |   |   |   |   |   |--- MonthlyCharges <= 61.60
# |   |   |   |   |   |   |   |--- TotalCharges <= 100.40
# |   |   |   |   |   |   |   |   |--- TotalCharges <= 50.30
# |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 46.35
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 45.67
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  45.67
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- TotalCharges >  46.35
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- TotalCharges >  50.30
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 51.05
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 27.35
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  27.35
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  51.05
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 57.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  57.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- TotalCharges >  100.40
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |--- MonthlyCharges >  61.60
# |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |--- PaperlessBilling_encode >  0.50
# |   |   |   |   |   |   |--- PhoneService_encode <= 0.50
# |   |   |   |   |   |   |   |--- MonthlyCharges <= 30.57
# |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 27.50
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 25.12
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 24.43
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges >  24.43
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  25.12
# |   |   |   |   |   |   |   |   |   |   |--- gender_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |   |--- gender_encode >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- MonthlyCharges >  27.50
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- MonthlyCharges >  30.57
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- PhoneService_encode >  0.50
# |   |   |   |   |   |   |   |--- MonthlyCharges <= 65.97
# |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 60.68
# |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 45.02
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 44.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  44.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- TotalCharges >  45.02
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 45.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges >  45.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |--- MonthlyCharges >  60.68
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- MonthlyCharges >  65.97
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |--- SeniorCitizen >  0.50
# |   |   |   |   |   |--- MonthlyCharges <= 43.65
# |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |--- MonthlyCharges >  43.65
# |   |   |   |   |   |   |--- MonthlyCharges <= 50.05
# |   |   |   |   |   |   |   |--- Partner_encode <= 0.50
# |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 45.15
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 44.50
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 90.98
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges >  90.98
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  44.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- MonthlyCharges >  45.15
# |   |   |   |   |   |   |   |   |   |--- PaperlessBilling_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- PaperlessBilling_encode >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- Partner_encode >  0.50
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- MonthlyCharges >  50.05
# |   |   |   |   |   |   |   |--- class: Yes
# |   |   |--- tenure >  2.50
# |   |   |   |--- MonthlyCharges <= 27.43
# |   |   |   |   |--- PhoneService_encode <= 0.50
# |   |   |   |   |   |--- MonthlyCharges <= 24.27
# |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |--- MonthlyCharges >  24.27
# |   |   |   |   |   |   |--- TotalCharges <= 72.60
# |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- TotalCharges >  72.60
# |   |   |   |   |   |   |   |--- MonthlyCharges <= 25.38
# |   |   |   |   |   |   |   |   |--- TotalCharges <= 112.95
# |   |   |   |   |   |   |   |   |   |--- PaperlessBilling_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- PaperlessBilling_encode >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- TotalCharges >  112.95
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- MonthlyCharges >  25.38
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |--- PhoneService_encode >  0.50
# |   |   |   |   |   |--- TotalCharges <= 397.23
# |   |   |   |   |   |   |--- TotalCharges <= 60.20
# |   |   |   |   |   |   |   |--- TotalCharges <= 58.57
# |   |   |   |   |   |   |   |   |--- gender_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- gender_encode >  0.50
# |   |   |   |   |   |   |   |   |   |--- PaperlessBilling_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- PaperlessBilling_encode >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- tenure <= 3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |   |--- tenure >  3.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- TotalCharges >  58.57
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- TotalCharges >  60.20
# |   |   |   |   |   |   |   |--- MonthlyCharges <= 19.27
# |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 19.23
# |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 174.40
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- TotalCharges >  174.40
# |   |   |   |   |   |   |   |   |   |   |--- tenure <= 13.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |   |--- tenure >  13.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- MonthlyCharges >  19.23
# |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 99.18
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- TotalCharges >  99.18
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- MonthlyCharges >  19.27
# |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 20.38
# |   |   |   |   |   |   |   |   |   |--- gender_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 167.88
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges >  167.88
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- gender_encode >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 341.88
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges >  341.88
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- MonthlyCharges >  20.38
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 20.93
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  20.93
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 23.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  23.38
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |--- TotalCharges >  397.23
# |   |   |   |   |   |   |--- class: Yes
# |   |   |   |--- MonthlyCharges >  27.43
# |   |   |   |   |--- TotalCharges <= 332.47
# |   |   |   |   |   |--- MonthlyCharges <= 55.42
# |   |   |   |   |   |   |--- tenure <= 8.50
# |   |   |   |   |   |   |   |--- MonthlyCharges <= 30.43
# |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 28.83
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- MonthlyCharges >  28.83
# |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 221.17
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- TotalCharges >  221.17
# |   |   |   |   |   |   |   |   |   |   |--- gender_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |   |--- gender_encode >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- MonthlyCharges >  30.43
# |   |   |   |   |   |   |   |   |--- TotalCharges <= 310.48
# |   |   |   |   |   |   |   |   |   |--- PaperlessBilling_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 45.58
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  45.58
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |--- PaperlessBilling_encode >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 50.93
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  50.93
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- TotalCharges >  310.48
# |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 331.05
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- TotalCharges >  331.05
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- tenure >  8.50
# |   |   |   |   |   |   |   |--- gender_encode <= 0.50
# |   |   |   |   |   |   |   |   |--- TotalCharges <= 305.50
# |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 295.22
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- TotalCharges >  295.22
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- TotalCharges >  305.50
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- gender_encode >  0.50
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |--- MonthlyCharges >  55.42
# |   |   |   |   |   |   |--- MonthlyCharges <= 67.12
# |   |   |   |   |   |   |   |--- TotalCharges <= 168.38
# |   |   |   |   |   |   |   |   |--- PaperlessBilling_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- PaperlessBilling_encode >  0.50
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 55.98
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  55.98
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- TotalCharges >  168.38
# |   |   |   |   |   |   |   |   |--- Partner_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- Partner_encode >  0.50
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 60.08
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  60.08
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 63.52
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  63.52
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |--- MonthlyCharges >  67.12
# |   |   |   |   |   |   |   |--- TotalCharges <= 248.12
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- TotalCharges >  248.12
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |--- TotalCharges >  332.47
# |   |   |   |   |   |--- TotalCharges <= 890.83
# |   |   |   |   |   |   |--- MonthlyCharges <= 58.67
# |   |   |   |   |   |   |   |--- MonthlyCharges <= 43.60
# |   |   |   |   |   |   |   |   |--- TotalCharges <= 353.32
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 37.30
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  37.30
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- TotalCharges >  353.32
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- MonthlyCharges >  43.60
# |   |   |   |   |   |   |   |   |--- PhoneService_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |--- Dependents_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 45.95
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  45.95
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- Dependents_encode >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- PhoneService_encode >  0.50
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 45.65
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 44.80
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  44.80
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  45.65
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 391.28
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges >  391.28
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |--- MonthlyCharges >  58.67
# |   |   |   |   |   |   |   |--- gender_encode <= 0.50
# |   |   |   |   |   |   |   |   |--- TotalCharges <= 618.73
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 59.75
# |   |   |   |   |   |   |   |   |   |   |--- tenure <= 8.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- tenure >  8.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  59.75
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- TotalCharges >  618.73
# |   |   |   |   |   |   |   |   |   |--- tenure <= 9.50
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 67.65
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  67.65
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- tenure >  9.50
# |   |   |   |   |   |   |   |   |   |   |--- PaperlessBilling_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |   |--- PaperlessBilling_encode >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |--- gender_encode >  0.50
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |--- TotalCharges >  890.83
# |   |   |   |   |   |   |--- PaperlessBilling_encode <= 0.50
# |   |   |   |   |   |   |   |--- SeniorCitizen <= 0.50
# |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 68.62
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- MonthlyCharges >  68.62
# |   |   |   |   |   |   |   |   |   |--- gender_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- gender_encode >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- SeniorCitizen >  0.50
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- PaperlessBilling_encode >  0.50
# |   |   |   |   |   |   |   |--- TotalCharges <= 1055.20
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- TotalCharges >  1055.20
# |   |   |   |   |   |   |   |   |--- class: No
# |   |--- MonthlyCharges >  69.22
# |   |   |--- TotalCharges <= 118.10
# |   |   |   |--- TotalCharges <= 75.68
# |   |   |   |   |--- MonthlyCharges <= 69.88
# |   |   |   |   |   |--- class: Yes
# |   |   |   |   |--- MonthlyCharges >  69.88
# |   |   |   |   |   |--- TotalCharges <= 75.47
# |   |   |   |   |   |   |--- PaperlessBilling_encode <= 0.50
# |   |   |   |   |   |   |   |--- TotalCharges <= 73.75
# |   |   |   |   |   |   |   |   |--- TotalCharges <= 70.25
# |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 70.05
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- TotalCharges >  70.05
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- TotalCharges >  70.25
# |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 71.00
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- TotalCharges >  71.00
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 71.22
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges >  71.22
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- TotalCharges >  73.75
# |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 75.00
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- MonthlyCharges >  75.00
# |   |   |   |   |   |   |   |   |   |--- gender_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- gender_encode >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |--- PaperlessBilling_encode >  0.50
# |   |   |   |   |   |   |   |--- MonthlyCharges <= 72.83
# |   |   |   |   |   |   |   |   |--- TotalCharges <= 71.88
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 71.40
# |   |   |   |   |   |   |   |   |   |   |--- gender_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- gender_encode >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  71.40
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- TotalCharges >  71.88
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- MonthlyCharges >  72.83
# |   |   |   |   |   |   |   |   |--- gender_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- gender_encode >  0.50
# |   |   |   |   |   |   |   |   |   |--- SeniorCitizen <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 74.33
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges >  74.33
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- SeniorCitizen >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |--- TotalCharges >  75.47
# |   |   |   |   |   |   |--- class: No
# |   |   |   |--- TotalCharges >  75.68
# |   |   |   |   |--- PaperlessBilling_encode <= 0.50
# |   |   |   |   |   |--- class: Yes
# |   |   |   |   |--- PaperlessBilling_encode >  0.50
# |   |   |   |   |   |--- Dependents_encode <= 0.50
# |   |   |   |   |   |   |--- SeniorCitizen <= 0.50
# |   |   |   |   |   |   |   |--- MonthlyCharges <= 95.72
# |   |   |   |   |   |   |   |   |--- TotalCharges <= 84.62
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 82.67
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 79.33
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  79.33
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  82.67
# |   |   |   |   |   |   |   |   |   |   |--- gender_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |   |--- gender_encode >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- TotalCharges >  84.62
# |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 89.17
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- TotalCharges >  89.17
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 89.40
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges >  89.40
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- MonthlyCharges >  95.72
# |   |   |   |   |   |   |   |   |--- TotalCharges <= 98.05
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- TotalCharges >  98.05
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- SeniorCitizen >  0.50
# |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |--- Dependents_encode >  0.50
# |   |   |   |   |   |   |--- TotalCharges <= 80.55
# |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- TotalCharges >  80.55
# |   |   |   |   |   |   |   |--- TotalCharges <= 90.47
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- TotalCharges >  90.47
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |--- TotalCharges >  118.10
# |   |   |   |--- MonthlyCharges <= 73.53
# |   |   |   |   |--- Dependents_encode <= 0.50
# |   |   |   |   |   |--- TotalCharges <= 482.42
# |   |   |   |   |   |   |--- TotalCharges <= 130.12
# |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |--- TotalCharges >  130.12
# |   |   |   |   |   |   |   |--- MonthlyCharges <= 71.12
# |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 70.62
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 70.45
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 221.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges >  221.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  70.45
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- MonthlyCharges >  70.62
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- MonthlyCharges >  71.12
# |   |   |   |   |   |   |   |   |--- TotalCharges <= 142.68
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- TotalCharges >  142.68
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |--- TotalCharges >  482.42
# |   |   |   |   |   |   |--- MonthlyCharges <= 70.85
# |   |   |   |   |   |   |   |--- tenure <= 10.50
# |   |   |   |   |   |   |   |   |--- TotalCharges <= 736.85
# |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 561.77
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 536.35
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges >  536.35
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- TotalCharges >  561.77
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- TotalCharges >  736.85
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- tenure >  10.50
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |--- MonthlyCharges >  70.85
# |   |   |   |   |   |   |   |--- MonthlyCharges <= 72.88
# |   |   |   |   |   |   |   |   |--- TotalCharges <= 1203.20
# |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 918.92
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- TotalCharges >  918.92
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 1045.83
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges >  1045.83
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- TotalCharges >  1203.20
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- MonthlyCharges >  72.88
# |   |   |   |   |   |   |   |   |--- TotalCharges <= 805.10
# |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 711.98
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- TotalCharges >  711.98
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- TotalCharges >  805.10
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |--- Dependents_encode >  0.50
# |   |   |   |   |   |--- MonthlyCharges <= 69.90
# |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |--- MonthlyCharges >  69.90
# |   |   |   |   |   |   |--- MonthlyCharges <= 70.55
# |   |   |   |   |   |   |   |--- MonthlyCharges <= 70.30
# |   |   |   |   |   |   |   |   |--- PaperlessBilling_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- PaperlessBilling_encode >  0.50
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- MonthlyCharges >  70.30
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- MonthlyCharges >  70.55
# |   |   |   |   |   |   |   |--- MonthlyCharges <= 72.85
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- MonthlyCharges >  72.85
# |   |   |   |   |   |   |   |   |--- tenure <= 12.50
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- tenure >  12.50
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |--- MonthlyCharges >  73.53
# |   |   |   |   |--- PaperlessBilling_encode <= 0.50
# |   |   |   |   |   |--- tenure <= 8.50
# |   |   |   |   |   |   |--- TotalCharges <= 430.23
# |   |   |   |   |   |   |   |--- MonthlyCharges <= 90.17
# |   |   |   |   |   |   |   |   |--- TotalCharges <= 381.32
# |   |   |   |   |   |   |   |   |   |--- SeniorCitizen <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 84.18
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  84.18
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- SeniorCitizen >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 77.15
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  77.15
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- TotalCharges >  381.32
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- MonthlyCharges >  90.17
# |   |   |   |   |   |   |   |   |--- Dependents_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- Dependents_encode >  0.50
# |   |   |   |   |   |   |   |   |   |--- tenure <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- tenure >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- TotalCharges >  430.23
# |   |   |   |   |   |   |   |--- MonthlyCharges <= 104.70
# |   |   |   |   |   |   |   |   |--- tenure <= 6.50
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- tenure >  6.50
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 75.52
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  75.52
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 647.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges >  647.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- MonthlyCharges >  104.70
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |--- tenure >  8.50
# |   |   |   |   |   |   |--- Dependents_encode <= 0.50
# |   |   |   |   |   |   |   |--- MonthlyCharges <= 85.18
# |   |   |   |   |   |   |   |   |--- tenure <= 10.50
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- tenure >  10.50
# |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 821.27
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- TotalCharges >  821.27
# |   |   |   |   |   |   |   |   |   |   |--- tenure <= 11.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |   |--- tenure >  11.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- MonthlyCharges >  85.18
# |   |   |   |   |   |   |   |   |--- TotalCharges <= 1144.35
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- TotalCharges >  1144.35
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 90.57
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 1279.25
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges >  1279.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  90.57
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 96.92
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  96.92
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |--- Dependents_encode >  0.50
# |   |   |   |   |   |   |   |--- TotalCharges <= 1192.28
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- TotalCharges >  1192.28
# |   |   |   |   |   |   |   |   |--- TotalCharges <= 1310.53
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- TotalCharges >  1310.53
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |--- PaperlessBilling_encode >  0.50
# |   |   |   |   |   |--- MonthlyCharges <= 84.38
# |   |   |   |   |   |   |--- TotalCharges <= 416.65
# |   |   |   |   |   |   |   |--- MonthlyCharges <= 82.15
# |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 79.92
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 75.67
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 75.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  75.60
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  75.67
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 217.27
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges >  217.27
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- MonthlyCharges >  79.92
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 80.55
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 80.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  80.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  80.55
# |   |   |   |   |   |   |   |   |   |   |--- Dependents_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |   |--- Dependents_encode >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- MonthlyCharges >  82.15
# |   |   |   |   |   |   |   |   |--- Partner_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- Partner_encode >  0.50
# |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 200.72
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- TotalCharges >  200.72
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 83.58
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  83.58
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- TotalCharges >  416.65
# |   |   |   |   |   |   |   |--- MonthlyCharges <= 74.58
# |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 74.17
# |   |   |   |   |   |   |   |   |   |--- SeniorCitizen <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- tenure <= 11.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |   |--- tenure >  11.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- SeniorCitizen >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- MonthlyCharges >  74.17
# |   |   |   |   |   |   |   |   |   |--- tenure <= 15.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- tenure >  15.50
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 74.38
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  74.38
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- MonthlyCharges >  74.58
# |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 79.03
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 75.80
# |   |   |   |   |   |   |   |   |   |   |--- tenure <= 6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |   |--- tenure >  6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  75.80
# |   |   |   |   |   |   |   |   |   |   |--- gender_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- gender_encode >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- MonthlyCharges >  79.03
# |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 874.27
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 429.62
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges >  429.62
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |--- TotalCharges >  874.27
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 1305.53
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges >  1305.53
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |--- MonthlyCharges >  84.38
# |   |   |   |   |   |   |--- TotalCharges <= 689.00
# |   |   |   |   |   |   |   |--- SeniorCitizen <= 0.50
# |   |   |   |   |   |   |   |   |--- tenure <= 7.50
# |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 522.92
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 500.85
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges >  500.85
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- TotalCharges >  522.92
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- tenure >  7.50
# |   |   |   |   |   |   |   |   |   |--- gender_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- gender_encode >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- SeniorCitizen >  0.50
# |   |   |   |   |   |   |   |   |--- TotalCharges <= 624.90
# |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 557.38
# |   |   |   |   |   |   |   |   |   |   |--- gender_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- gender_encode >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- TotalCharges >  557.38
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- TotalCharges >  624.90
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- TotalCharges >  689.00
# |   |   |   |   |   |   |   |--- Dependents_encode <= 0.50
# |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 95.98
# |   |   |   |   |   |   |   |   |   |--- SeniorCitizen <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 1033.92
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges >  1033.92
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- SeniorCitizen >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- tenure <= 13.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |   |--- tenure >  13.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- MonthlyCharges >  95.98
# |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 919.08
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 100.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  100.45
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- TotalCharges >  919.08
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 110.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  110.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- Dependents_encode >  0.50
# |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 100.88
# |   |   |   |   |   |   |   |   |   |--- gender_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 923.18
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges >  923.18
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- gender_encode >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 95.70
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  95.70
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- MonthlyCharges >  100.88
# |   |   |   |   |   |   |   |   |   |--- class: No
# |--- tenure >  16.50
# |   |--- MonthlyCharges <= 69.97
# |   |   |--- MonthlyCharges <= 28.55
# |   |   |   |--- tenure <= 61.50
# |   |   |   |   |--- tenure <= 52.50
# |   |   |   |   |   |--- tenure <= 25.50
# |   |   |   |   |   |   |--- TotalCharges <= 652.85
# |   |   |   |   |   |   |   |--- PhoneService_encode <= 0.50
# |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 24.65
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- MonthlyCharges >  24.65
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- PhoneService_encode >  0.50
# |   |   |   |   |   |   |   |   |--- TotalCharges <= 391.28
# |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 390.62
# |   |   |   |   |   |   |   |   |   |   |--- tenure <= 19.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |   |--- tenure >  19.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- TotalCharges >  390.62
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- TotalCharges >  391.28
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |--- TotalCharges >  652.85
# |   |   |   |   |   |   |   |--- Partner_encode <= 0.50
# ...
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 3477.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges >  3477.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  101.35
# |   |   |   |   |   |   |   |   |   |   |--- tenure <= 40.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- tenure >  40.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |--- SeniorCitizen >  0.50
# |   |   |   |   |   |--- Dependents_encode <= 0.50
# |   |   |   |   |   |   |--- MonthlyCharges <= 73.60
# |   |   |   |   |   |   |   |--- tenure <= 37.50
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- tenure >  37.50
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- MonthlyCharges >  73.60
# |   |   |   |   |   |   |   |--- MonthlyCharges <= 79.25
# |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 75.45
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 74.58
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  74.58
# |   |   |   |   |   |   |   |   |   |   |--- Partner_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |   |--- Partner_encode >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- MonthlyCharges >  75.45
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- MonthlyCharges >  79.25
# |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 84.97
# |   |   |   |   |   |   |   |   |   |--- tenure <= 32.50
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 80.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  80.17
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- tenure >  32.50
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 83.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  83.60
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- MonthlyCharges >  84.97
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 89.88
# |   |   |   |   |   |   |   |   |   |   |--- tenure <= 25.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |   |--- tenure >  25.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  89.88
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 1618.57
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges >  1618.57
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |--- Dependents_encode >  0.50
# |   |   |   |   |   |   |--- TotalCharges <= 3552.75
# |   |   |   |   |   |   |   |--- MonthlyCharges <= 79.72
# |   |   |   |   |   |   |   |   |--- tenure <= 34.50
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- tenure >  34.50
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- MonthlyCharges >  79.72
# |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 97.73
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- MonthlyCharges >  97.73
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 99.65
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  99.65
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |--- TotalCharges >  3552.75
# |   |   |   |   |   |   |   |--- class: Yes
# |   |   |--- tenure >  41.50
# |   |   |   |--- tenure <= 69.50
# |   |   |   |   |--- MonthlyCharges <= 93.67
# |   |   |   |   |   |--- SeniorCitizen <= 0.50
# |   |   |   |   |   |   |--- MonthlyCharges <= 70.25
# |   |   |   |   |   |   |   |--- TotalCharges <= 3981.12
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- TotalCharges >  3981.12
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |--- MonthlyCharges >  70.25
# |   |   |   |   |   |   |   |--- MonthlyCharges <= 74.70
# |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- MonthlyCharges >  74.70
# |   |   |   |   |   |   |   |   |--- TotalCharges <= 4518.38
# |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 4515.45
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 3226.48
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges >  3226.48
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |--- TotalCharges >  4515.45
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- TotalCharges >  4518.38
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 74.95
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  74.95
# |   |   |   |   |   |   |   |   |   |   |--- tenure <= 66.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- tenure >  66.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |--- SeniorCitizen >  0.50
# |   |   |   |   |   |   |--- tenure <= 54.50
# |   |   |   |   |   |   |   |--- PaperlessBilling_encode <= 0.50
# |   |   |   |   |   |   |   |   |--- tenure <= 45.50
# |   |   |   |   |   |   |   |   |   |--- Partner_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- Partner_encode >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- tenure >  45.50
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- PaperlessBilling_encode >  0.50
# |   |   |   |   |   |   |   |   |--- TotalCharges <= 3625.40
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 70.85
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  70.85
# |   |   |   |   |   |   |   |   |   |   |--- Partner_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- Partner_encode >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- TotalCharges >  3625.40
# |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 4136.20
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- TotalCharges >  4136.20
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 86.20
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  86.20
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |--- tenure >  54.50
# |   |   |   |   |   |   |   |--- tenure <= 65.50
# |   |   |   |   |   |   |   |   |--- tenure <= 55.50
# |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 4840.00
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- TotalCharges >  4840.00
# |   |   |   |   |   |   |   |   |   |   |--- PaperlessBilling_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |   |--- PaperlessBilling_encode >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- tenure >  55.50
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- tenure >  65.50
# |   |   |   |   |   |   |   |   |--- Partner_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- Partner_encode >  0.50
# |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 6091.57
# |   |   |   |   |   |   |   |   |   |   |--- tenure <= 67.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- tenure >  67.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- TotalCharges >  6091.57
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |--- MonthlyCharges >  93.67
# |   |   |   |   |   |--- MonthlyCharges <= 110.40
# |   |   |   |   |   |   |--- PaperlessBilling_encode <= 0.50
# |   |   |   |   |   |   |   |--- MonthlyCharges <= 94.00
# |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- MonthlyCharges >  94.00
# |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 110.33
# |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 4459.93
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 4208.12
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges >  4208.12
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- TotalCharges >  4459.93
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 99.45
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  99.45
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |--- MonthlyCharges >  110.33
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- PaperlessBilling_encode >  0.50
# |   |   |   |   |   |   |   |--- gender_encode <= 0.50
# |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 98.12
# |   |   |   |   |   |   |   |   |   |--- tenure <= 66.00
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 94.80
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  94.80
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- tenure >  66.00
# |   |   |   |   |   |   |   |   |   |   |--- tenure <= 68.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |   |--- tenure >  68.00
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- MonthlyCharges >  98.12
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 98.88
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  98.88
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 99.95
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  99.95
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 22
# |   |   |   |   |   |   |   |--- gender_encode >  0.50
# |   |   |   |   |   |   |   |   |--- TotalCharges <= 5428.70
# |   |   |   |   |   |   |   |   |   |--- tenure <= 50.50
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 99.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  99.03
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- tenure >  50.50
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 105.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  105.05
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |--- TotalCharges >  5428.70
# |   |   |   |   |   |   |   |   |   |--- Dependents_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 94.17
# |   |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  94.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |--- Dependents_encode >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- SeniorCitizen <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- SeniorCitizen >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |--- MonthlyCharges >  110.40
# |   |   |   |   |   |   |--- TotalCharges <= 4791.50
# |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- TotalCharges >  4791.50
# |   |   |   |   |   |   |   |--- MonthlyCharges <= 117.32
# |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 113.20
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 112.75
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 7468.78
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |   |--- TotalCharges >  7468.78
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  112.75
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- MonthlyCharges >  113.20
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |--- MonthlyCharges >  117.32
# |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 118.47
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- MonthlyCharges >  118.47
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |--- tenure >  69.50
# |   |   |   |   |--- TotalCharges <= 8678.62
# |   |   |   |   |   |--- MonthlyCharges <= 92.42
# |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |--- MonthlyCharges >  92.42
# |   |   |   |   |   |   |--- TotalCharges <= 6590.97
# |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |--- TotalCharges >  6590.97
# |   |   |   |   |   |   |   |--- tenure <= 70.50
# |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 115.25
# |   |   |   |   |   |   |   |   |   |--- gender_encode <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |--- gender_encode >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 102.02
# |   |   |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  102.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- MonthlyCharges >  115.25
# |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |--- tenure >  70.50
# |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 109.28
# |   |   |   |   |   |   |   |   |   |--- TotalCharges <= 8056.80
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges <= 107.88
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- MonthlyCharges >  107.88
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- TotalCharges >  8056.80
# |   |   |   |   |   |   |   |   |   |   |--- class: Yes
# |   |   |   |   |   |   |   |   |--- MonthlyCharges >  109.28
# |   |   |   |   |   |   |   |   |   |--- class: No
# |   |   |   |   |--- TotalCharges >  8678.62
# |   |   |   |   |   |--- class: Yes

# %% [markdown]
# ### 3-2) 피처 중요도 시각화 하기
#
# * 해당 이미지는 예시로 모델의 학습 결과에 따라 다르게 나올 수 있습니다.
#
# <img src="https://i.imgur.com/EtcMpCy.png" width="500">

# %%
# feature_importances_ 를 통해 모델의 피처 중요도를 추출합니다.

model.feature_importances_
# Out:
# array([0.02193898, 0.23504016, 0.35453812, 0.27215748, 0.03054588,
#        0.02921848, 0.02460781, 0.00695076, 0.02500233])

# %%
# 피처 중요도를 시각화 합니다.
# 여기에 구현해 주세요. 위 예시 이미지를 참고합니다.
sns.barplot(x=model.feature_importances_, y=feature_names)
# Out:
# <Axes: >

# %% [markdown]
# ### 3-3) 정확도(Accuracy)구하기
# - 모델이 얼마나 잘 예측했는지 측정해 봅니다.
# - 시험을 보고 나서 몇 개 맞았는지 틀렸는지 채점해 보는 과정과 유사하다고 보면 됩니다.
# - 실전 문제에서는 답이 없어서 우리가 예측을 해야겠지만 이 실습은 정답이 있는 모의고사 입니다.
# - 모의고사를 보면 내 실력이 어느정도 되는지 예측해 보는 것처럼 점수를 측정해 봅니다.

# %%
# 빈칸을 채워 정확도(accuracy) 를 구해주세요.
# 정답과 같이 예측한 값은 True 로 나오게 됩니다.
# True == 1 이기 때문에 평균값을 내면 정답을 맞춘 비율을 구할 수 있습니다.

from sklearn.metrics import accuracy_score

accuracy_score(y_test, y_predict)
# Out:
# 0.7299218194740583
